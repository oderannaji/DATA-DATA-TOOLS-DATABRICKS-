# %%
# %sh
pwd
# Out:
# /Workspace/Users/o.i.nnaji@edu.salford.ac.uk

# %%
dbutils.fs.ls('file:/')
# Out:
# [FileInfo(path='file:/tmp/', name='tmp/', size=4096, modificationTime=1739557672140),
#  FileInfo(path='file:/lib/', name='lib/', size=4096, modificationTime=1739557330593),
#  FileInfo(path='file:/lib64/', name='lib64/', size=4096, modificationTime=1739557243243),
#  FileInfo(path='file:/dev/', name='dev/', size=560, modificationTime=1739557337401),
#  FileInfo(path='file:/var/', name='var/', size=4096, modificationTime=1739557330681),
#  FileInfo(path='file:/etc/', name='etc/', size=4096, modificationTime=1739557324657),
#  FileInfo(path='file:/usr/', name='usr/', size=4096, modificationTime=1739557330629),
#  FileInfo(path='file:/boot/', name='boot/', size=4096, modificationTime=1739557324653),
#  FileInfo(path='file:/root/', name='root/', size=4096, modificationTime=1739557540204),
#  FileInfo(path='file:/bin/', name='bin/', size=32768, modificationTime=1739557330553),
#  FileInfo(path='file:/opt/', name='opt/', size=4096, modificationTime=1739557307582),
#  FileInfo(path='file:/srv/', name='srv/', size=4096, modificationTime=1739557324657),
#  FileInfo(path='file:/media/', name='media/', size=4096, modificationTime=1739557324657),
#  FileInfo(path='file:/home/', name='home/', size=4096, modificationTime=1739557307582),
#  FileInfo(path='file:/proc/', name='proc/', size=0, modificationTime=1739557331901),
#  FileInfo(path='file:/libx32/', name='libx32/', size=4096, modificationTime=1739557330629),
#  FileInfo(path='file:/databricks/', name='databricks/', size=4096, modificationTime=1739557530348),
#  FileInfo(path='file:/BUILD.bazel', name='BUILD.bazel', size=228, modificationTime=1739557229572),
#  FileInfo(path='file:/mnt/', name='mnt/', size=4096, modificationTime=1739557334297),
#  FileInfo(path='file:/sbin/', name='sbin/', size=12288, modificationTime=1739557330633),
#  FileInfo(path='file:/sys/', name='sys/', size=0, modificationTime=1739557331901),
#  FileInfo(path='file:/lib32/', name='lib32/', size=4096, modificationTime=1739557330629),
#  FileInfo(path='file:/run/', name='run/', size=420, modificationTime=1739557423211),
#  FileInfo(path='file:/Volumes/', name='Volumes/', size=4096, modificationTime=1739557338582),
#  FileInfo(path='file:/Workspace/', name='Workspace/', size=4096, modificationTime=1739557338031),
#  FileInfo(path='file:/local_disk0/', name='local_disk0/', size=4096, modificationTime=1739557421887),
#  FileInfo(path='file:/dbfs/', name='dbfs/', size=4096, modificationTime=1739557337425)]

# %%
dbutils.fs.ls('FileStore/tables/')
# Out:
# [FileInfo(path='dbfs:/FileStore/tables/account-models/', name='account-models/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/accounts/', name='accounts/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/accounts.zip', name='accounts.zip', size=5297592, modificationTime=1739555633000),
#  FileInfo(path='dbfs:/FileStore/tables/activation-models/', name='activation-models/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/activations/', name='activations/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/activations-1.zip', name='activations-1.zip', size=8411369, modificationTime=1738170810000),
#  FileInfo(path='dbfs:/FileStore/tables/activations-2.zip', name='activations-2.zip', size=8411369, modificationTime=1739548977000),
#  FileInfo(path='dbfs:/FileStore/tables/activations.zip', name='activations.zip', size=8411369, modificationTime=1738170694000),
#  FileInfo(path='dbfs:/FileStore/tables/flood-1.zip', name='flood-1.zip', size=52053, modificationTime=1739383385000),
#  FileInfo(path='dbfs:/FileStore/tables/flood.csv', name='flood.csv', size=128984, modificationTime=1739383593000),
#  FileInfo(path='dbfs:/FileStore/tables/flood.zip', name='flood.zip', size=52053, modificationTime=1739383337000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/', name='logs/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/logs-1.zip', name='logs-1.zip', size=18168065, modificationTime=1738174579000),
#  FileInfo(path='dbfs:/FileStore/tables/logs-2.zip', name='logs-2.zip', size=18168065, modificationTime=1738174963000),
#  FileInfo(path='dbfs:/FileStore/tables/logs-3.zip', name='logs-3.zip', size=18168065, modificationTime=1738175067000),
#  FileInfo(path='dbfs:/FileStore/tables/logs-4.zip', name='logs-4.zip', size=18168065, modificationTime=1739555650000),
#  FileInfo(path='dbfs:/FileStore/tables/logs.zip', name='logs.zip', size=18168065, modificationTime=1738173004000),
#  FileInfo(path='dbfs:/FileStore/tables/test-1.json', name='test-1.json', size=17958, modificationTime=1739501024000),
#  FileInfo(path='dbfs:/FileStore/tables/test.json', name='test.json', size=17958, modificationTime=1737563569000),
#  FileInfo(path='dbfs:/FileStore/tables/webpage/', name='webpage/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/webpage-1.zip', name='webpage-1.zip', size=1582, modificationTime=1739378903000),
#  FileInfo(path='dbfs:/FileStore/tables/webpage-2.zip', name='webpage-2.zip', size=1582, modificationTime=1739378915000),
#  FileInfo(path='dbfs:/FileStore/tables/webpage-3.zip', name='webpage-3.zip', size=1582, modificationTime=1739379223000),
#  FileInfo(path='dbfs:/FileStore/tables/webpage-4.zip', name='webpage-4.zip', size=1582, modificationTime=1739379292000),
#  FileInfo(path='dbfs:/FileStore/tables/webpage_1_.zip', name='webpage_1_.zip', size=1582, modificationTime=1739379031000),
#  FileInfo(path='dbfs:/FileStore/tables/webpage_files_all/', name='webpage_files_all/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/webpage_files_jpg/', name='webpage_files_jpg/', size=0, modificationTime=0)]

# %%
dbutils.fs.cp('FileStore/tables/activations.zip/', 'file:/tmp/')
# Out:
# True

# %%
# %sh
ls /tmp/
# Out:
# Rserv
# RtmpDjHKRf
# activations.zip
# chauffeur-daemon-params
# chauffeur-daemon.pid
# chauffeur-env.sh
# custom-spark.conf
# driver-daemon-params
# driver-daemon.pid
# driver-env.sh
# hsperfdata_root
# systemd-private-f9ce07439a3c4cc48e979121aa5ecbf8-systemd-logind.service-0RUYo8
# systemd-private-f9ce07439a3c4cc48e979121aa5ecbf8-systemd-resolved.service-wDybAa
# tmp.B6csKUedQA
# webpage-4.zip

# %%
# %sh

unzip -d /tmp/ /tmp/activations.zip
# Out:
# Archive:  /tmp/activations.zip
#    creating: /tmp/activations/
#   inflating: /tmp/activations/2011-04.json
#   inflating: /tmp/activations/2013-10.json
#   inflating: /tmp/activations/2011-09.json
#   inflating: /tmp/activations/2011-02.json
#   inflating: /tmp/activations/2009-12.json
#   inflating: /tmp/activations/2010-10.json
#   inflating: /tmp/activations/2009-11.json
#   inflating: /tmp/activations/2014-03.json
#   inflating: /tmp/activations/2012-02.json
#   inflating: /tmp/activations/2013-07.json
#   inflating: /tmp/activations/2013-04.json
#   inflating: /tmp/activations/2010-11.json
#   inflating: /tmp/activations/2009-02.json
#   inflating: /tmp/activations/2012-05.json
#   inflating: /tmp/activations/2013-12.json
#   inflating: /tmp/activations/2009-07.json
#   inflating: /tmp/activations/2012-04.json
#   inflating: /tmp/activations/2009-03.json
#   inflating: /tmp/activations/2008-12.json
#   inflating: /tmp/activations/2011-05.json
#   inflating: /tmp/activations/2009-09.json
#   inflating: /tmp/activations/2012-03.json
#   inflating: /tmp/activations/2013-02.json
#   inflating: /tmp/activations/2011-06.json
#   inflating: /tmp/activations/2010-02.json
#   inflating: /tmp/activations/2008-11.json
#   inflating: /tmp/activations/2008-10.json
#   inflating: /tmp/activations/2013-09.json
#   inflating: /tmp/activations/2011-07.json
#   inflating: /tmp/activations/2013-06.json
#   inflating: /tmp/activations/2010-05.json
#   inflating: /tmp/activations/2014-01.json
#   inflating: /tmp/activations/2012-06.json
#   inflating: /tmp/activations/2012-12.json
#   inflating: /tmp/activations/2009-10.json
#   inflating: /tmp/activations/2010-01.json
#   inflating: /tmp/activations/2011-10.json
#   inflating: /tmp/activations/2012-07.json
#   inflating: /tmp/activations/2012-10.json
#   inflating: /tmp/activations/2012-11.json
#   inflating: /tmp/activations/2010-12.json
#   inflating: /tmp/activations/2011-11.json
#   inflating: /tmp/activations/2011-08.json
#   inflating: /tmp/activations/2013-11.json
#   inflating: /tmp/activations/2013-03.json
#   inflating: /tmp/activations/2009-04.json
#   inflating: /tmp/activations/2012-09.json
#   inflating: /tmp/activations/2010-03.json
#   inflating: /tmp/activations/2009-06.json
#   inflating: /tmp/activations/2014-02.json
#   inflating: /tmp/activations/2009-01.json
#   inflating: /tmp/activations/2011-01.json
#   inflating: /tmp/activations/2010-09.json
#   inflating: /tmp/activations/2010-04.json
#   inflating: /tmp/activations/2010-06.json
#   inflating: /tmp/activations/2013-01.json
#   inflating: /tmp/activations/2013-08.json
#   inflating: /tmp/activations/2011-12.json
#   inflating: /tmp/activations/2009-05.json
#   inflating: /tmp/activations/2013-05.json
#   inflating: /tmp/activations/2011-03.json
#   inflating: /tmp/activations/2010-07.json
#   inflating: /tmp/activations/2012-08.json
#   inflating: /tmp/activations/2012-01.json
#   inflating: /tmp/activations/2009-08.json
#   inflating: /tmp/activations/2010-08.json

# %%
# %sh
ls /tmp/activations
# Out:
# 2008-10.json
# 2008-11.json
# 2008-12.json
# 2009-01.json
# 2009-02.json
# 2009-03.json
# 2009-04.json
# 2009-05.json
# 2009-06.json
# 2009-07.json
# 2009-08.json
# 2009-09.json
# 2009-10.json
# 2009-11.json
# 2009-12.json
# 2010-01.json
# 2010-02.json
# 2010-03.json
# 2010-04.json
# 2010-05.json
# 2010-06.json
# 2010-07.json
# 2010-08.json
# 2010-09.json
# 2010-10.json
# 2010-11.json
# 2010-12.json
# 2011-01.json
# 2011-02.json
# 2011-03.json
# 2011-04.json
# 2011-05.json
# 2011-06.json
# 2011-07.json
# 2011-08.json
# 2011-09.json
# 2011-10.json
# 2011-11.json
# 2011-12.json
# 2012-01.json
# 2012-02.json
# 2012-03.json
# 2012-04.json
# 2012-05.json
# 2012-06.json
# 2012-07.json
# 2012-08.json
# 2012-09.json
# 2012-10.json
# 2012-11.json
# 2012-12.json
# 2013-01.json
# 2013-02.json
# 2013-03.json
# 2013-04.json
# 2013-05.json
# 2013-06.json
# 2013-07.json
# 2013-08.json
# 2013-09.json
# 2013-10.json
# 2013-11.json
# 2013-12.json
# 2014-01.json
# 2014-02.json
# 2014-03.json

# %%
dbutils.fs.mkdirs('FileStore/tables/activations')
# Out:
# True

# %%
dbutils.fs.mv('file:/tmp/activations', 'FileStore/tables/activations', True)
# Out:
# True

# %%
dbutils.fs.ls('FileStore/tables/activations/')
# Out:
# [FileInfo(path='dbfs:/FileStore/tables/activations/2008-10.json', name='2008-10.json', size=17958, modificationTime=1739557694000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2008-11.json', name='2008-11.json', size=69467, modificationTime=1739557694000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2008-12.json', name='2008-12.json', size=64783, modificationTime=1739557692000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2009-01.json', name='2009-01.json', size=85111, modificationTime=1739557695000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2009-02.json', name='2009-02.json', size=63749, modificationTime=1739557682000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2009-03.json', name='2009-03.json', size=81257, modificationTime=1739557689000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2009-04.json', name='2009-04.json', size=77942, modificationTime=1739557696000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2009-05.json', name='2009-05.json', size=84937, modificationTime=1739557680000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2009-06.json', name='2009-06.json', size=83592, modificationTime=1739557691000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2009-07.json', name='2009-07.json', size=81819, modificationTime=1739557680000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2009-08.json', name='2009-08.json', size=74548, modificationTime=1739557692000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2009-09.json', name='2009-09.json', size=78221, modificationTime=1739557695000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2009-10.json', name='2009-10.json', size=85751, modificationTime=1739557690000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2009-11.json', name='2009-11.json', size=87756, modificationTime=1739557693000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2009-12.json', name='2009-12.json', size=90772, modificationTime=1739557685000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2010-01.json', name='2010-01.json', size=181273, modificationTime=1739557685000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2010-02.json', name='2010-02.json', size=180555, modificationTime=1739557694000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2010-03.json', name='2010-03.json', size=189089, modificationTime=1739557684000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2010-04.json', name='2010-04.json', size=188924, modificationTime=1739557693000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2010-05.json', name='2010-05.json', size=213902, modificationTime=1739557683000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2010-06.json', name='2010-06.json', size=221724, modificationTime=1739557681000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2010-07.json', name='2010-07.json', size=216971, modificationTime=1739557679000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2010-08.json', name='2010-08.json', size=227790, modificationTime=1739557681000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2010-09.json', name='2010-09.json', size=220632, modificationTime=1739557691000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2010-10.json', name='2010-10.json', size=223382, modificationTime=1739557686000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2010-11.json', name='2010-11.json', size=197397, modificationTime=1739557684000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2010-12.json', name='2010-12.json', size=222284, modificationTime=1739557685000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2011-01.json', name='2011-01.json', size=416104, modificationTime=1739557694000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2011-02.json', name='2011-02.json', size=396798, modificationTime=1739557687000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2011-03.json', name='2011-03.json', size=445626, modificationTime=1739557682000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2011-04.json', name='2011-04.json', size=430525, modificationTime=1739557692000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2011-05.json', name='2011-05.json', size=439483, modificationTime=1739557693000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2011-06.json', name='2011-06.json', size=428603, modificationTime=1739557692000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2011-07.json', name='2011-07.json', size=439938, modificationTime=1739557693000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2011-08.json', name='2011-08.json', size=455153, modificationTime=1739557682000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2011-09.json', name='2011-09.json', size=437586, modificationTime=1739557683000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2011-10.json', name='2011-10.json', size=472058, modificationTime=1739557685000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2011-11.json', name='2011-11.json', size=449723, modificationTime=1739557685000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2011-12.json', name='2011-12.json', size=477450, modificationTime=1739557693000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2012-01.json', name='2012-01.json', size=923068, modificationTime=1739557695000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2012-02.json', name='2012-02.json', size=891243, modificationTime=1739557694000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2012-03.json', name='2012-03.json', size=952135, modificationTime=1739557687000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2012-04.json', name='2012-04.json', size=937497, modificationTime=1739557681000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2012-05.json', name='2012-05.json', size=947643, modificationTime=1739557680000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2012-06.json', name='2012-06.json', size=901965, modificationTime=1739557686000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2012-07.json', name='2012-07.json', size=969209, modificationTime=1739557683000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2012-08.json', name='2012-08.json', size=994500, modificationTime=1739557687000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2012-09.json', name='2012-09.json', size=946015, modificationTime=1739557688000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2012-10.json', name='2012-10.json', size=1004706, modificationTime=1739557690000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2012-11.json', name='2012-11.json', size=942948, modificationTime=1739557684000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2012-12.json', name='2012-12.json', size=984888, modificationTime=1739557680000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2013-01.json', name='2013-01.json', size=1018983, modificationTime=1739557682000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2013-02.json', name='2013-02.json', size=927261, modificationTime=1739557695000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2013-03.json', name='2013-03.json', size=1051372, modificationTime=1739557691000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2013-04.json', name='2013-04.json', size=1017264, modificationTime=1739557679000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2013-05.json', name='2013-05.json', size=1029567, modificationTime=1739557692000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2013-06.json', name='2013-06.json', size=1004932, modificationTime=1739557695000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2013-07.json', name='2013-07.json', size=1068533, modificationTime=1739557682000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2013-08.json', name='2013-08.json', size=1071469, modificationTime=1739557689000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2013-09.json', name='2013-09.json', size=998698, modificationTime=1739557684000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2013-10.json', name='2013-10.json', size=1067196, modificationTime=1739557686000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2013-11.json', name='2013-11.json', size=6425136, modificationTime=1739557691000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2013-12.json', name='2013-12.json', size=3519683, modificationTime=1739557689000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2014-01.json', name='2014-01.json', size=3314540, modificationTime=1739557688000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2014-02.json', name='2014-02.json', size=2712737, modificationTime=1739557688000),
#  FileInfo(path='dbfs:/FileStore/tables/activations/2014-03.json', name='2014-03.json', size=1240487, modificationTime=1739557690000)]

# %%
len(dbutils.fs.ls('FileStore/tables/activations/'))
# Out:
# 66

# %%
dbutils.fs.head('FileStore/tables/activations/2008-10.json')
# Out:
# '{\n  "activations": {\n    "activation": [\n      {\n        "@timestamp": "1225462088",\n        "@type": "phone",\n        "account-number": "9763",\n        "device-id": "debea35e-3ecd-4ee7-b0dd-ad428d953f32",\n        "phone-number": "7600763387",\n        "model": "MeeToo 1.0"\n      },\n      {\n        "@timestamp": "1225461447",\n        "@type": "phone",\n        "account-number": "426",\n        "device-id": "38a1566d-524e-4137-bad8-b597d09b54b0",\n        "phone-number": "5102521038",\n        "model": "Titanic 1000"\n      },\n      {\n        "@timestamp": "1225446947",\n        "@type": "phone",\n        "account-number": "383",\n        "device-id": "513024a3-a828-4674-9ff6-041e9a851f18",\n        "phone-number": "9162206560",\n        "model": "Sorrento F00L"\n      },\n      {\n        "@timestamp": "1225445908",\n        "@type": "phone",\n        "account-number": "404",\n        "device-id": "93d7d0eb-7551-4e11-ab59-91f34c04378f",\n        "phone-number": "6506862748",\n        "model": "MeeToo 1.0"\n      },\n      {\n        "@timestamp": "1225444099",\n        "@type": "phone",\n        "account-number": "393",\n        "device-id": "75faa3a2-31d6-48ec-a1a9-da4c882c7b75",\n        "phone-number": "6504786402",\n        "model": "iFruit 1"\n      },\n      {\n        "@timestamp": "1225421991",\n        "@type": "phone",\n        "account-number": "53",\n        "device-id": "a6482e48-d347-4ec5-b010-9d9a3b13d999",\n        "phone-number": "6503155055",\n        "model": "MeeToo 1.0"\n      },\n      {\n        "@timestamp": "1225412236",\n        "@type": "phone",\n        "account-number": "96",\n        "device-id": "351a0384-9af6-4621-ada8-3eba9fb2734c",\n        "phone-number": "4152163825",\n        "model": "iFruit 1"\n      },\n      {\n        "@timestamp": "1225406348",\n        "@type": "phone",\n        "account-number": "283",\n        "device-id": "04ad366c-c023-4d01-8493-8ec97d3ff5cc",\n        "phone-number": "5109683453",\n        "model": "Sorrento F00L"\n      },\n      {\n        "@timestamp": "1225400017",\n        "@type": "phone",\n        "account-number": "464",\n        "device-id": "e4ceefc4-8765-4beb-8b10-9b3d73eec535",\n        "phone-number": "6504367851",\n        "model": "MeeToo 1.0"\n      },\n      {\n        "@timestamp": "1225386391",\n        "@type": "phone",\n        "account-number": "475",\n        "device-id": "31fe0811-c4fb-40b8-bc59-8386fe2f5d8e",\n        "phone-number": "6504313792",\n        "model": "Titanic 1000"\n      },\n      {\n        "@timestamp": "1225371984",\n        "@type": "phone",\n        "account-number": "479",\n        "device-id": "38f76751-3236-4e99-80c9-c4b0a030108e",\n        "phone-number": "6507811206",\n        "model": "iFruit 1"\n      },\n      {\n        "@timestamp": "1225355475",\n        "@type": "phone",\n        "account-number": "306",\n        "device-id": "d743093b-8bcf-4ede-a475-4bc29936bc5e",\n        "phone-number": "4158787317",\n        "model": "Titanic 1000"\n      },\n      {\n        "@timestamp": "1225349055",\n        "@type": "phone",\n        "account-number": "14045",\n        "device-id": "1f568e8d-268a-4171-8a50-94c70fbfdf90",\n        "phone-number": "9098824980",\n        "model": "MeeToo 1.0"\n      },\n      {\n        "@timestamp": "1225347793",\n        "@type": "phone",\n        "account-number": "6482",\n        "device-id": "c14cbc3d-8b55-49bb-931d-7b2472aaa750",\n        "phone-number": "4082887060",\n        "model": "Sorrento F00L"\n      },\n      {\n        "@timestamp": "1225345397",\n        "@type": "phone",\n        "account-number": "349",\n        "device-id": "04c2fc8e-2f4f-4c7a-ad26-146c26deec87",\n        "phone-number": "6502434241",\n        "model": "MeeToo 1.0"\n      },\n      {\n        "@timestamp": "1225333766",\n        "@type": "phone",\n        "account-number": "124",\n        "device-id": "74d1341a-8da9-4de7-86f6-ec5285665ef2",\n        "phone-number": "5103920538",\n  ...

# %%
myrdd1 = sc.wholeTextFiles('/FileStore/tables/activations/')

# %%
myrdd1.take(2)
# Out:
# [('dbfs:/FileStore/tables/activations/2008-10.json',
#   '{\n  "activations": {\n    "activation": [\n      {\n        "@timestamp": "1225462088",\n        "@type": "phone",\n        "account-number": "9763",\n        "device-id": "debea35e-3ecd-4ee7-b0dd-ad428d953f32",\n        "phone-number": "7600763387",\n        "model": "MeeToo 1.0"\n      },\n      {\n        "@timestamp": "1225461447",\n        "@type": "phone",\n        "account-number": "426",\n        "device-id": "38a1566d-524e-4137-bad8-b597d09b54b0",\n        "phone-number": "5102521038",\n        "model": "Titanic 1000"\n      },\n      {\n        "@timestamp": "1225446947",\n        "@type": "phone",\n        "account-number": "383",\n        "device-id": "513024a3-a828-4674-9ff6-041e9a851f18",\n        "phone-number": "9162206560",\n        "model": "Sorrento F00L"\n      },\n      {\n        "@timestamp": "1225445908",\n        "@type": "phone",\n        "account-number": "404",\n        "device-id": "93d7d0eb-7551-4e11-ab59-91f34c04378f",\n        "phone-number": "6506862748",\n        "model": "MeeToo 1.0"\n      },\n      {\n        "@timestamp": "1225444099",\n        "@type": "phone",\n        "account-number": "393",\n        "device-id": "75faa3a2-31d6-48ec-a1a9-da4c882c7b75",\n        "phone-number": "6504786402",\n        "model": "iFruit 1"\n      },\n      {\n        "@timestamp": "1225421991",\n        "@type": "phone",\n        "account-number": "53",\n        "device-id": "a6482e48-d347-4ec5-b010-9d9a3b13d999",\n        "phone-number": "6503155055",\n        "model": "MeeToo 1.0"\n      },\n      {\n        "@timestamp": "1225412236",\n        "@type": "phone",\n        "account-number": "96",\n        "device-id": "351a0384-9af6-4621-ada8-3eba9fb2734c",\n        "phone-number": "4152163825",\n        "model": "iFruit 1"\n      },\n      {\n        "@timestamp": "1225406348",\n        "@type": "phone",\n        "account-number": "283",\n        "device-id": "04ad366c-c023-4d01-8493-8ec97d3ff5cc",\n        "phone-number": "5109683453",\n        "model": "Sorrento F00L"\n      },\n      {\n        "@timestamp": "1225400017",\n        "@type": "phone",\n        "account-number": "464",\n        "device-id": "e4ceefc4-8765-4beb-8b10-9b3d73eec535",\n        "phone-number": "6504367851",\n        "model": "MeeToo 1.0"\n      },\n      {\n        "@timestamp": "1225386391",\n        "@type": "phone",\n        "account-number": "475",\n        "device-id": "31fe0811-c4fb-40b8-bc59-8386fe2f5d8e",\n        "phone-number": "6504313792",\n        "model": "Titanic 1000"\n      },\n      {\n        "@timestamp": "1225371984",\n        "@type": "phone",\n        "account-number": "479",\n        "device-id": "38f76751-3236-4e99-80c9-c4b0a030108e",\n        "phone-number": "6507811206",\n        "model": "iFruit 1"\n      },\n      {\n        "@timestamp": "1225355475",\n        "@type": "phone",\n        "account-number": "306",\n        "device-id": "d743093b-8bcf-4ede-a475-4bc29936bc5e",\n        "phone-number": "4158787317",\n        "model": "Titanic 1000"\n      },\n      {\n        "@timestamp": "1225349055",\n        "@type": "phone",\n        "account-number": "14045",\n        "device-id": "1f568e8d-268a-4171-8a50-94c70fbfdf90",\n        "phone-number": "9098824980",\n        "model": "MeeToo 1.0"\n      },\n      {\n        "@timestamp": "1225347793",\n        "@type": "phone",\n        "account-number": "6482",\n        "device-id": "c14cbc3d-8b55-49bb-931d-7b2472aaa750",\n        "phone-number": "4082887060",\n        "model": "Sorrento F00L"\n      },\n      {\n        "@timestamp": "1225345397",\n        "@type": "phone",\n        "account-number": "349",\n        "device-id": "04c2fc8e-2f4f-4c7a-ad26-146c26deec87",\n        "phone-number": "6502434241",\n        "model": "MeeToo 1.0"\n      },\n      {\n        "@timestamp": "1225333766",\n        "@type": "phone",\n        "account-number": "124",\n        "device-id": "74d1341a-8da9-4de7-86f6-ec5285665ef2",\n        "phone-number": "5103920538",\ ...
#  ('dbfs:/FileStore/tables/activations/2008-11.json',
#   '{\n  "activations": {\n    "activation": [\n      {\n        "@timestamp": "1228068581",\n        "@type": "phone",\n        "account-number": "93893",\n        "device-id": "b1d33f97-4f7f-4760-b6d5-2354b8ede7f9",\n        "phone-number": "8313151801",\n        "model": "Titanic 1100"\n      },\n      {\n        "@timestamp": "1228064129",\n        "@type": "phone",\n        "account-number": "10524",\n        "device-id": "e2e9a69e-9e9d-4cf0-a3be-b948c8f9bcd0",\n        "phone-number": "3102505580",\n        "model": "Titanic 1000"\n      },\n      {\n        "@timestamp": "1228062743",\n        "@type": "phone",\n        "account-number": "116",\n        "device-id": "f0f3bf10-4849-4409-a68b-d70be46729bc",\n        "phone-number": "5101189988",\n        "model": "Sorrento F00L"\n      },\n      {\n        "@timestamp": "1228062084",\n        "@type": "phone",\n        "account-number": "428",\n        "device-id": "fab0463c-aa81-4b0a-86dc-9b2dc336f9ea",\n        "phone-number": "5106385454",\n        "model": "Titanic 1100"\n      },\n      {\n        "@timestamp": "1228061914",\n        "@type": "phone",\n        "account-number": "237",\n        "device-id": "65a54ea6-21d3-406d-806a-fb060675e525",\n        "phone-number": "6503135322",\n        "model": "Titanic 1000"\n      },\n      {\n        "@timestamp": "1228057594",\n        "@type": "phone",\n        "account-number": "51",\n        "device-id": "f4f80206-62ee-4a62-81fe-fae3f67d9ac5",\n        "phone-number": "6509811731",\n        "model": "Titanic 1100"\n      },\n      {\n        "@timestamp": "1228048822",\n        "@type": "phone",\n        "account-number": "195",\n        "device-id": "a1a52d81-a215-4109-b2ea-05c5c3f88023",\n        "phone-number": "9163594089",\n        "model": "iFruit 1"\n      },\n      {\n        "@timestamp": "1228048751",\n        "@type": "phone",\n        "account-number": "38",\n        "device-id": "f4edd2b5-f875-4ddf-ab05-e88b42304cfe",\n        "phone-number": "4153177265",\n        "model": "Titanic 1100"\n      },\n      {\n        "@timestamp": "1228045159",\n        "@type": "phone",\n        "account-number": "147",\n        "device-id": "8030b68d-9fe2-4a32-b7ef-a4d01458bad5",\n        "phone-number": "7074994246",\n        "model": "Titanic 1100"\n      },\n      {\n        "@timestamp": "1228044426",\n        "@type": "phone",\n        "account-number": "120",\n        "device-id": "3bb4eab1-6059-4563-ba83-652ed13183d8",\n        "phone-number": "4159244097",\n        "model": "Sorrento F00L"\n      },\n      {\n        "@timestamp": "1228043667",\n        "@type": "phone",\n        "account-number": "8386",\n        "device-id": "7fe71ddb-f628-404b-92b1-d83185144941",\n        "phone-number": "8055015287",\n        "model": "Sorrento F00L"\n      },\n      {\n        "@timestamp": "1228037258",\n        "@type": "phone",\n        "account-number": "412",\n        "device-id": "c73b3e86-4b6b-4570-93df-0c63c88b9832",\n        "phone-number": "6503191552",\n        "model": "Sorrento F00L"\n      },\n      {\n        "@timestamp": "1228024901",\n        "@type": "phone",\n        "account-number": "458",\n        "device-id": "8ab5b4b5-c37c-44b4-af3f-383df36dd933",\n        "phone-number": "6505547003",\n        "model": "MeeToo 1.0"\n      },\n      {\n        "@timestamp": "1228011938",\n        "@type": "phone",\n        "account-number": "14",\n        "device-id": "356562ec-25f7-4fa0-80c3-04dde199f28d",\n        "phone-number": "9163145431",\n        "model": "Titanic 1100"\n      },\n      {\n        "@timestamp": "1227994723",\n        "@type": "phone",\n        "account-number": "265",\n        "device-id": "6529c933-a516-4806-8789-b1cec9a906bc",\n        "phone-number": "5102513154",\n        "model": "Sorrento F00L"\n      },\n      {\n        "@timestamp": "1227991927",\n        "@type": "phone",\n        "account-number": "128",\n        "device-id": "d04b2829-82d6-40e8-99a4-6f36de7f37aa",\n        "phone-num ...

# %%
import json
myrdd2 = myrdd1.map(lambda s: json.loads(s[1]))

# %%
myrdd2.take(2)
# Out:
# [{'activations': {'activation': [{'@timestamp': '1225462088',
#      '@type': 'phone',
#      'account-number': '9763',
#      'device-id': 'debea35e-3ecd-4ee7-b0dd-ad428d953f32',
#      'phone-number': '7600763387',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225461447',
#      '@type': 'phone',
#      'account-number': '426',
#      'device-id': '38a1566d-524e-4137-bad8-b597d09b54b0',
#      'phone-number': '5102521038',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225446947',
#      '@type': 'phone',
#      'account-number': '383',
#      'device-id': '513024a3-a828-4674-9ff6-041e9a851f18',
#      'phone-number': '9162206560',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225445908',
#      '@type': 'phone',
#      'account-number': '404',
#      'device-id': '93d7d0eb-7551-4e11-ab59-91f34c04378f',
#      'phone-number': '6506862748',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225444099',
#      '@type': 'phone',
#      'account-number': '393',
#      'device-id': '75faa3a2-31d6-48ec-a1a9-da4c882c7b75',
#      'phone-number': '6504786402',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225421991',
#      '@type': 'phone',
#      'account-number': '53',
#      'device-id': 'a6482e48-d347-4ec5-b010-9d9a3b13d999',
#      'phone-number': '6503155055',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225412236',
#      '@type': 'phone',
#      'account-number': '96',
#      'device-id': '351a0384-9af6-4621-ada8-3eba9fb2734c',
#      'phone-number': '4152163825',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225406348',
#      '@type': 'phone',
#      'account-number': '283',
#      'device-id': '04ad366c-c023-4d01-8493-8ec97d3ff5cc',
#      'phone-number': '5109683453',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225400017',
#      '@type': 'phone',
#      'account-number': '464',
#      'device-id': 'e4ceefc4-8765-4beb-8b10-9b3d73eec535',
#      'phone-number': '6504367851',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225386391',
#      '@type': 'phone',
#      'account-number': '475',
#      'device-id': '31fe0811-c4fb-40b8-bc59-8386fe2f5d8e',
#      'phone-number': '6504313792',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225371984',
#      '@type': 'phone',
#      'account-number': '479',
#      'device-id': '38f76751-3236-4e99-80c9-c4b0a030108e',
#      'phone-number': '6507811206',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225355475',
#      '@type': 'phone',
#      'account-number': '306',
#      'device-id': 'd743093b-8bcf-4ede-a475-4bc29936bc5e',
#      'phone-number': '4158787317',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225349055',
#      '@type': 'phone',
#      'account-number': '14045',
#      'device-id': '1f568e8d-268a-4171-8a50-94c70fbfdf90',
#      'phone-number': '9098824980',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225347793',
#      '@type': 'phone',
#      'account-number': '6482',
#      'device-id': 'c14cbc3d-8b55-49bb-931d-7b2472aaa750',
#      'phone-number': '4082887060',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225345397',
#      '@type': 'phone',
#      'account-number': '349',
#      'device-id': '04c2fc8e-2f4f-4c7a-ad26-146c26deec87',
#      'phone-number': '6502434241',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225333766',
#      '@type': 'phone',
#      'account-number': '124',
#      'device-id': '74d1341a-8da9-4de7-86f6-ec5285665ef2',
#      'phone-number': '5103920538',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225333728',
#      '@type': 'phone',
#      'account-number': '247',
#      'device-id': '8ca7ba2f-5b8a-4574-abbb-de5a18221894',
#      'phone-number': '6509604844',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225320127',
#      '@type': 'phone',
#      'account-number': '88',
#      'device-id': '9f7daca9-5faf-4cfd-b863-85d510464945',
#      'phone-number': '6501458572',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225319701',
#      '@type': 'phone',
#      'account-number': '2939',
#      'device-id': '18970270-86f0-4bac-ba03-24eb8518f082',
#      'phone-number': '9161294398',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225317616',
#      '@type': 'phone',
#      'account-number': '314',
#      'device-id': 'ae3cb61f-5318-4b74-bb05-9de91a66bb10',
#      'phone-number': '6509019772',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225315853',
#      '@type': 'phone',
#      'account-number': '396',
#      'device-id': '767d106f-4a25-4177-afe5-8f081fc68cd7',
#      'phone-number': '6500312075',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225278009',
#      '@type': 'phone',
#      'account-number': '6881',
#      'device-id': 'fb8f6fe5-c2f5-43e5-a0b5-032c1b437989',
#      'phone-number': '5625307326',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225275474',
#      '@type': 'phone',
#      'account-number': '234',
#      'device-id': '31485143-2104-4f4d-bceb-4866f484e27f',
#      'phone-number': '9166314637',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225246830',
#      '@type': 'phone',
#      'account-number': '34209',
#      'device-id': '7dcd293d-b59d-48ea-bfe5-af623fa67b81',
#      'phone-number': '7022095507',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225242164',
#      '@type': 'phone',
#      'account-number': '369',
#      'device-id': '8cadd7a9-b799-4ebb-8314-2b8a9716ed86',
#      'phone-number': '5108109471',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225230097',
#      '@type': 'phone',
#      'account-number': '255',
#      'device-id': '6d515f2b-4fc8-4916-916f-f7ec7750ee3e',
#      'phone-number': '4159552347',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225229238',
#      '@type': 'phone',
#      'account-number': '13',
#      'device-id': '9163f7b0-9957-47f2-8a56-cb195ea1adc4',
#      'phone-number': '4153335996',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225174761',
#      '@type': 'phone',
#      'account-number': '142',
#      'device-id': '558b13f3-783f-4434-a85f-97413146f835',
#      'phone-number': '5109700907',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225161449',
#      '@type': 'phone',
#      'account-number': '11',
#      'device-id': '678dc546-57ca-47fa-a387-184248f610dd',
#      'phone-number': '5109726353',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225157362',
#      '@type': 'phone',
#      'account-number': '61',
#      'device-id': 'be33c35d-1fa6-4f61-83e4-439a095ae4cc',
#      'phone-number': '9162581613',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225152905',
#      '@type': 'phone',
#      'account-number': '1554',
#      'device-id': 'ce9468cc-8d98-4dc6-90b5-e72a44c64a21',
#      'phone-number': '4153912267',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225149813',
#      '@type': 'phone',
#      'account-number': '165',
#      'device-id': '52c76b69-c8d2-479c-88af-cbf0e95e3e5e',
#      'phone-number': '5104562352',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225120582',
#      '@type': 'phone',
#      'account-number': '128224',
#      'device-id': '416578b7-5684-4848-b97a-3587784eaa12',
#      'phone-number': '2133389934',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225118290',
#      '@type': 'phone',
#      'account-number': '394',
#      'device-id': '6b879605-0cdc-4200-834f-205b74b40dca',
#      'phone-number': '7070593543',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225102200',
#      '@type': 'phone',
#      'account-number': '433',
#      'device-id': 'fd12614c-b21c-4b26-a825-4bfd63492149',
#      'phone-number': '9165391636',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225086639',
#      '@type': 'phone',
#      'account-number': '448',
#      'device-id': '39f94f2b-3a58-49bd-bc48-3885cd42badc',
#      'phone-number': '6503935352',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225078279',
#      '@type': 'phone',
#      'account-number': '440',
#      'device-id': '0bf181b2-25b7-4541-87d8-15f6d7a0ccb9',
#      'phone-number': '6505467053',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225067942',
#      '@type': 'phone',
#      'account-number': '240',
#      'device-id': '3966e7ae-0954-4ea7-bde6-b35ee0f39c30',
#      'phone-number': '7079354042',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225061652',
#      '@type': 'phone',
#      'account-number': '460',
#      'device-id': '5b8530d4-f467-42e3-818d-c81e20cfd1c1',
#      'phone-number': '6500282551',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225058673',
#      '@type': 'phone',
#      'account-number': '275',
#      'device-id': '42be5c11-8931-46bf-af06-c87c3f580337',
#      'phone-number': '4155493875',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225047870',
#      '@type': 'phone',
#      'account-number': '4638',
#      'device-id': '7164d9d1-d2e0-439d-9aee-1fd20da48df3',
#      'phone-number': '5101970154',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225039607',
#      '@type': 'phone',
#      'account-number': '171',
#      'device-id': 'dc0e941a-90d4-4c84-ac7d-383e276dad84',
#      'phone-number': '5105209310',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225033098',
#      '@type': 'phone',
#      'account-number': '213',
#      'device-id': '5c42d2ac-d92f-4ef1-acee-47d39a909b11',
#      'phone-number': '5101004303',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1224994511',
#      '@type': 'phone',
#      'account-number': '324',
#      'device-id': '71a6ed8d-a751-44bf-8b38-320a49c12a9b',
#      'phone-number': '6501654645',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1224990765',
#      '@type': 'phone',
#      'account-number': '98121',
#      'device-id': '9a6d0b23-8845-460d-aa47-91c82d8fc480',
#      'phone-number': '6618825932',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1224983389',
#      '@type': 'phone',
#      'account-number': '363',
#      'device-id': '254ab846-f1d4-4c85-a658-46ee5e848c53',
#      'phone-number': '6505506140',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1224956920',
#      '@type': 'phone',
#      'account-number': '52',
#      'device-id': '330f46cc-de2a-49d3-aa93-6ff761de7d5a',
#      'phone-number': '4151228388',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1224956441',
#      '@type': 'phone',
#      'account-number': '286',
#      'device-id': '78d4f9fe-b6e3-40c2-91d5-18ff95a074e5',
#      'phone-number': '5107058174',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1224946254',
#      '@type': 'phone',
#      'account-number': '13702',
#      'device-id': 'b024cf7d-496f-4f6e-bbc1-772d13ca1617',
#      'phone-number': '5416107165',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1224944970',
#      '@type': 'phone',
#      'account-number': '345',
#      'device-id': 'cd1c8a9d-066c-4f6f-b08f-dc119d827699',
#      'phone-number': '5103859765',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1224938467',
#      '@type': 'phone',
#      'account-number': '36906',
#      'device-id': '9043cf20-d816-4f17-af72-020767ae14e0',
#      'phone-number': '5411008209',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1224907589',
#      '@type': 'phone',
#      'account-number': '413',
#      'device-id': '0e487cf9-6923-4891-94f7-7b12695b72fd',
#      'phone-number': '5107080443',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1224847655',
#      '@type': 'phone',
#      'account-number': '459',
#      'device-id': '5aff8521-f91b-48f6-a69a-156caa236bd0',
#      'phone-number': '4157500638',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1224831370',
#      '@type': 'phone',
#      'account-number': '144',
#      'device-id': 'e7f833e9-276e-4f3b-9710-9d3106a5141a',
#      'phone-number': '5108355566',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1224817110',
#      '@type': 'phone',
#      'account-number': '373',
#      'device-id': '0f7b8628-873a-4d1b-9b86-0bfe40f2f668',
#      'phone-number': '5109247675',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1224812967',
#      '@type': 'phone',
#      'account-number': '46849',
#      'device-id': 'b99f88ef-5ad2-4c62-bbc6-ca2756b4467c',
#      'phone-number': '5414191932',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1224805157',
#      '@type': 'phone',
#      'account-number': '252',
#      'device-id': '6c71ca45-ddae-4191-98e8-01f3bc2a1220',
#      'phone-number': '5109508609',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1224803105',
#      '@type': 'phone',
#      'account-number': '1',
#      'device-id': '7eb61253-55cd-4309-8f17-129089fee461',
#      'phone-number': '5100032418',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1224782486',
#      '@type': 'phone',
#      'account-number': '21566',
#      'device-id': '2bebd773-39ac-4d31-a23e-06eb2991ac26',
#      'phone-number': '9165053364',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1224781467',
#      '@type': 'phone',
#      'account-number': '154',
#      'device-id': '1923ef7c-3067-4f7c-93f7-c867bd31a39f',
#      'phone-number': '5106577100',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1224778387',
#      '@type': 'phone',
#      'account-number': '46168',
#      'device-id': 'fb7f3575-c523-47bf-be76-889a07a5af9c',
#      'phone-number': '5037703631',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1224771580',
#      '@type': 'phone',
#      'account-number': '3838',
#      'device-id': '46ec037a-c72d-4e4a-aff6-a7498dbd8b1f',
#      'phone-number': '6501253886',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1224769655',
#      '@type': 'phone',
#      'account-number': '21821',
#      'device-id': '2cef3c7a-6fbe-42d1-9a7f-19854a959700',
#      'phone-number': '6262624197',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1224747397',
#      '@type': 'phone',
#      'account-number': '204',
#      'device-id': '04d374ba-3441-4aa4-88d9-057c0721ba0f',
#      'phone-number': '7076669246',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1224736965',
#      '@type': 'phone',
#      'account-number': '131',
#      'device-id': 'a53f23f2-a57f-4655-90fd-f53a0a05d587',
#      'phone-number': '4151707647',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1224729378',
#      '@type': 'phone',
#      'account-number': '474',
#      'device-id': '4bd55037-72e7-432f-a1b1-2a94a4df9f16',
#      'phone-number': '5102971778',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1224725663',
#      '@type': 'phone',
#      'account-number': '146',
#      'device-id': '5c66d63f-3384-49d6-8cba-65a28b34ba30',
#      'phone-number': '7070285635',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1224719408',
#      '@type': 'phone',
#      'account-number': '2063',
#      'device-id': '21b927a6-c4f6-43c0-bc11-abe77abfd6bc',
#      'phone-number': '6503298970',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1224688572',
#      '@type': 'phone',
#      'account-number': '374',
#      'device-id': 'cc8ef6ff-93de-4a55-b2ed-888b3bd9740b',
#      'phone-number': '7073442709',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1224652877',
#      '@type': 'phone',
#      'account-number': '89',
#      'device-id': 'bbc9f0e7-8315-4ada-832d-56db3083d507',
#      'phone-number': '5104067433',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1224652432',
#      '@type': 'phone',
#      'account-number': '194',
#      'device-id': '7997d06a-664d-45f2-9c1e-4896b1450e28',
#      'phone-number': '7071451183',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1224641243',
#      '@type': 'phone',
#      'account-number': '269',
#      'device-id': '07895a7d-1b66-4b7c-84d7-b1592a03437c',
#      'phone-number': '4153026986',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1224628700',
#      '@type': 'phone',
#      'account-number': '155',
#      'device-id': 'cd84b041-5d4e-4fc5-977e-46231507e173',
#      'phone-number': '4153927390',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1224585351',
#      '@type': 'phone',
#      'account-number': '405',
#      'device-id': 'b53bb445-5bc6-489b-9dd5-9de6370a19fe',
#      'phone-number': '4151697001',
#      'model': 'MeeToo 1.0'}]}},
#  {'activations': {'activation': [{'@timestamp': '1228068581',
#      '@type': 'phone',
#      'account-number': '93893',
#      'device-id': 'b1d33f97-4f7f-4760-b6d5-2354b8ede7f9',
#      'phone-number': '8313151801',
#      'model': 'Titanic 1100'},
#     {'@timestamp': '1228064129',
#      '@type': 'phone',
#      'account-number': '10524',
#      'device-id': 'e2e9a69e-9e9d-4cf0-a3be-b948c8f9bcd0',
#      'phone-number': '3102505580',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1228062743',
#      '@type': 'phone',
#      'account-number': '116',
#      'device-id': 'f0f3bf10-4849-4409-a68b-d70be46729bc',
#      'phone-number': '5101189988',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1228062084',
#      '@type': 'phone',
#      'account-number': '428',
#      'device-id': 'fab0463c-aa81-4b0a-86dc-9b2dc336f9ea',
#      'phone-number': '5106385454',
#      'model': 'Titanic 1100'},
#     {'@timestamp': '1228061914',
#      '@type': 'phone',
#      'account-number': '237',
#      'device-id': '65a54ea6-21d3-406d-806a-fb060675e525',
#      'phone-number': '6503135322',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1228057594',
#      '@type': 'phone',
#      'account-number': '51',
#      'device-id': 'f4f80206-62ee-4a62-81fe-fae3f67d9ac5',
#      'phone-number': '6509811731',
#      'model': 'Titanic 1100'},
#     {'@timestamp': '1228048822',
#      '@type': 'phone',
#      'account-number': '195',
#      'device-id': 'a1a52d81-a215-4109-b2ea-05c5c3f88023',
#      'phone-number': '9163594089',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1228048751',
#      '@type': 'phone',
#      'account-number': '38',
#      'device-id': 'f4edd2b5-f875-4ddf-ab05-e88b42304cfe',
#      'phone-number': '4153177265',
#      'model': 'Titanic 1100'},
#     {'@timestamp': '1228045159',
#      '@type': 'phone',
#      'account-number': '147',
#      'device-id': '8030b68d-9fe2-4a32-b7ef-a4d01458bad5',
#      'phone-number': '7074994246',
#      'model': 'Titanic 1100'},
#     {'@timestamp': '1228044426',
#      '@type': 'phone',
#      'account-number': '120',
#      'device-id': '3bb4eab1-6059-4563-ba83-652ed13183d8',
#      'phone-number': '4159244097',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1228043667',
#      '@type': 'phone',
#      'account-number': '8386',
#      'device-id': '7fe71ddb-f628-404b-92b1-d83185144941',
#      'phone-number': '8055015287',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1228037258',
#      '@type': 'phone',
#      'account-number': '412',
#      'device-id': 'c73b3e86-4b6b-4570-93df-0c63c88b9832',
#      'phone-number': '6503191552',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1228024901',
#      '@type': 'phone',
#      'account-number': '458',
#      'device-id': '8ab5b4b5-c37c-44b4-af3f-383df36dd933',
#      'phone-number': '6505547003',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1228011938',
#      '@type': 'phone',
#      'account-number': '14',
#      'device-id': '356562ec-25f7-4fa0-80c3-04dde199f28d',
#      'phone-number': '9163145431',
#      'model': 'Titanic 1100'},
#     {'@timestamp': '1227994723',
#      '@type': 'phone',
#      'account-number': '265',
#      'device-id': '6529c933-a516-4806-8789-b1cec9a906bc',
#      'phone-number': '5102513154',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227991927',
#      '@type': 'phone',
#      'account-number': '128',
#      'device-id': 'd04b2829-82d6-40e8-99a4-6f36de7f37aa',
#      'phone-number': '5104700295',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227990060',
#      '@type': 'phone',
#      'account-number': '257',
#      'device-id': '481fac04-9b3d-4149-8c3c-7e44e0193e77',
#      'phone-number': '6500930741',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227977355',
#      '@type': 'phone',
#      'account-number': '23566',
#      'device-id': '34b9b80f-14bd-4a8d-ac1e-450d6f027b33',
#      'phone-number': '5414803587',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227970298',
#      '@type': 'phone',
#      'account-number': '107295',
#      'device-id': 'f5acd15f-03af-47bc-a058-96b3579d043d',
#      'phone-number': '9164044669',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227961962',
#      '@type': 'phone',
#      'account-number': '27',
#      'device-id': '39e73634-abb2-4908-9f0c-b03a21385522',
#      'phone-number': '5106498890',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227958445',
#      '@type': 'phone',
#      'account-number': '333',
#      'device-id': '50a49dc9-ace7-4bda-9bd2-3f5fc287628d',
#      'phone-number': '9169038715',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227957356',
#      '@type': 'phone',
#      'account-number': '121392',
#      'device-id': '5c83cc16-01ab-4d3a-9396-beb184e2a9f6',
#      'phone-number': '2138590851',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227919061',
#      '@type': 'phone',
#      'account-number': '335',
#      'device-id': 'fa1d9c67-b73a-487a-a82d-1fce0b10d697',
#      'phone-number': '5108634189',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227913705',
#      '@type': 'phone',
#      'account-number': '923',
#      'device-id': '80619a86-288a-4ff8-b8e3-dc163b7dd6e6',
#      'phone-number': '6504194308',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227908713',
#      '@type': 'phone',
#      'account-number': '41',
#      'device-id': '7cde8c96-c803-4e48-b52d-8e0c0a4b24e1',
#      'phone-number': '5109215080',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227888786',
#      '@type': 'phone',
#      'account-number': '397',
#      'device-id': 'e9953f37-bef4-4093-8045-0a998b8ab001',
#      'phone-number': '5107577696',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227873981',
#      '@type': 'phone',
#      'account-number': '149',
#      'device-id': '5fbac38d-5150-4499-a087-91a3c2ba15da',
#      'phone-number': '4151278270',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227865367',
#      '@type': 'phone',
#      'account-number': '476',
#      'device-id': '5fb78138-dc78-4103-a091-55a9d4bf5efa',
#      'phone-number': '4157817332',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227859689',
#      '@type': 'phone',
#      'account-number': '4',
#      'device-id': 'c0b0c922-7fd4-46bb-a6d6-68d4064f22d5',
#      'phone-number': '6503198619',
#      'model': 'Titanic 1100'},
#     {'@timestamp': '1227830952',
#      '@type': 'phone',
#      'account-number': '114',
#      'device-id': 'f538a7a6-f6cd-48af-b313-5773be6b7d0d',
#      'phone-number': '5106048663',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227826151',
#      '@type': 'phone',
#      'account-number': '189',
#      'device-id': '9b134b4c-07d8-42c1-af92-eeb1fd211c98',
#      'phone-number': '5100136428',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227819767',
#      '@type': 'phone',
#      'account-number': '49',
#      'device-id': '612810c3-b7e3-43e9-83bc-998a4cda0e6b',
#      'phone-number': '5107438525',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227806793',
#      '@type': 'phone',
#      'account-number': '292',
#      'device-id': '45a59589-828c-4d75-b297-e1b7ad511f04',
#      'phone-number': '4159862789',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227802883',
#      '@type': 'phone',
#      'account-number': '56',
#      'device-id': '4c0342b7-af47-4464-9e22-49a1a261ffcd',
#      'phone-number': '9162005319',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227786174',
#      '@type': 'phone',
#      'account-number': '322',
#      'device-id': '6dd56894-b7d8-490c-95f8-46e6251f764f',
#      'phone-number': '7075317849',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227785572',
#      '@type': 'phone',
#      'account-number': '372',
#      'device-id': 'dd1d353e-abbc-4adc-93a0-ea30060766d6',
#      'phone-number': '9161076178',
#      'model': 'Titanic 1100'},
#     {'@timestamp': '1227782087',
#      '@type': 'phone',
#      'account-number': '270',
#      'device-id': '19452078-e2b8-41ad-af17-a77b5a1b5652',
#      'phone-number': '4150621455',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227769405',
#      '@type': 'phone',
#      'account-number': '339',
#      'device-id': 'f1bffcf8-f105-4983-9d47-cc96c048ce0d',
#      'phone-number': '4154302141',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227762105',
#      '@type': 'phone',
#      'account-number': '2031',
#      'device-id': 'af56cf3e-77a5-4688-b784-c92f34314c83',
#      'phone-number': '4151135639',
#      'model': 'Titanic 1100'},
#     {'@timestamp': '1227738017',
#      '@type': 'phone',
#      'account-number': '353',
#      'device-id': 'a1fa8883-5a06-4504-a6b1-ff5a6a034bfb',
#      'phone-number': '5101143561',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227720362',
#      '@type': 'phone',
#      'account-number': '125',
#      'device-id': '903a774b-dd0f-4cf2-890b-c9ba4dba28dc',
#      'phone-number': '7070672305',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227719309',
#      '@type': 'phone',
#      'account-number': '99887',
#      'device-id': 'e7b4d7ce-6ef8-4962-a592-43e0ebe6aece',
#      'phone-number': '5415417522',
#      'model': 'Titanic 1100'},
#     {'@timestamp': '1227717892',
#      '@type': 'phone',
#      'account-number': '472',
#      'device-id': 'deb0c95c-f6aa-4bcb-8b72-7a853ccb75c0',
#      'phone-number': '5105433467',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227711502',
#      '@type': 'phone',
#      'account-number': '8939',
#      'device-id': '04c3c276-3075-418b-8a51-b93883909896',
#      'phone-number': '5104872043',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227698854',
#      '@type': 'phone',
#      'account-number': '370',
#      'device-id': '2e16c752-0c31-4441-8b7b-f9fb1200a647',
#      'phone-number': '5109097241',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227688988',
#      '@type': 'phone',
#      'account-number': '28434',
#      'device-id': 'a7d5b546-fa0e-4902-8d43-e1ac83bdcec1',
#      'phone-number': '6199063286',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227676109',
#      '@type': 'phone',
#      'account-number': '300',
#      'device-id': '3c2503ae-836e-449b-acd6-776483d2355e',
#      'phone-number': '5108557383',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227672804',
#      '@type': 'phone',
#      'account-number': '289',
#      'device-id': 'f98d0b0f-cf84-4464-a412-303db57039a0',
#      'phone-number': '9164554012',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227650267',
#      '@type': 'phone',
#      'account-number': '151',
#      'device-id': '2b064958-4cc8-49fc-8aca-ee7c909c8fbe',
#      'phone-number': '5100707947',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227646491',
#      '@type': 'phone',
#      'account-number': '12066',
#      'device-id': 'cc3d0cbf-03a3-4dad-b534-36346ca08983',
#      'phone-number': '3108467208',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227641513',
#      '@type': 'phone',
#      'account-number': '22255',
#      'device-id': '3dbd189d-787b-4d14-9dc1-620bd08cc104',
#      'phone-number': '6197367895',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227634697',
#      '@type': 'phone',
#      'account-number': '364',
#      'device-id': '1492df55-6de9-4862-83ba-daabcba71a98',
#      'phone-number': '9164414254',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227618293',
#      '@type': 'phone',
#      'account-number': '409',
#      'device-id': '608da6ca-1252-48cf-a87b-89f500e063a5',
#      'phone-number': '6502425864',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227617658',
#      '@type': 'phone',
#      'account-number': '290',
#      'device-id': '085cc0f2-a13a-420b-b673-656d96d3d0ad',
#      'phone-number': '5101843345',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227605543',
#      '@type': 'phone',
#      'account-number': '2603',
#      'device-id': '3f45619a-2958-459f-8808-3c022da95ba6',
#      'phone-number': '4156590803',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227584515',
#      '@type': 'phone',
#      'account-number': '96006',
#      'device-id': '2cb7096f-d1f6-431d-bed6-e71469a27210',
#      'phone-number': '7473762531',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227584445',
#      '@type': 'phone',
#      'account-number': '414',
#      'device-id': '89682648-98b3-4dc8-8c37-5cdf0d716a25',
#      'phone-number': '5106847547',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227577650',
#      '@type': 'phone',
#      'account-number': '271',
#      'device-id': '27143f4c-17ab-4027-a01a-ce35d456ea8a',
#      'phone-number': '5105340442',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227569822',
#      '@type': 'phone',
#      'account-number': '384',
#      'device-id': '1a7b0b16-20e4-4204-b31b-7bc7aa33053d',
#      'phone-number': '6507494892',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227566876',
#      '@type': 'phone',
#      'account-number': '132',
#      'device-id': '640b3f2e-0903-4f33-82e8-074e0fa047ca',
#      'phone-number': '5101808531',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227556137',
#      '@type': 'phone',
#      'account-number': '297',
#      'device-id': '093a8b70-55ca-4248-970a-09ecbf651b4a',
#      'phone-number': '5100478907',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227554198',
#      '@type': 'phone',
#      'account-number': '82',
#      'device-id': '6ef9260a-b7f6-44c3-b50c-bbd7e69b81dd',
#      'phone-number': '4159613291',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227547822',
#      '@type': 'phone',
#      'account-number': '69821',
#      'device-id': 'cfec70f7-14bf-4335-b925-752764177d82',
#      'phone-number': '5039528927',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227545979',
#      '@type': 'phone',
#      'account-number': '175',
#      'device-id': '1775cf6b-05c1-4bf2-b431-316688ff7736',
#      'phone-number': '7071408613',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227534768',
#      '@type': 'phone',
#      'account-number': '73',
#      'device-id': '544ec3d6-5526-417c-9786-cfefc63662b9',
#      'phone-number': '5101152162',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227533625',
#      '@type': 'phone',
#      'account-number': '355',
#      'device-id': '534f8d7b-4df7-41ea-a97b-537b484847a3',
#      'phone-number': '5109162875',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227526739',
#      '@type': 'phone',
#      'account-number': '26873',
#      'device-id': '2c02a50b-48c5-41a9-96fa-30c6aea016e2',
#      'phone-number': '4150858149',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227473968',
#      '@type': 'phone',
#      'account-number': '299',
#      'device-id': 'cd37b386-0656-4bf5-97a6-f97fb7139ec2',
#      'phone-number': '7071317120',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227468354',
#      '@type': 'phone',
#      'account-number': '199',
#      'device-id': 'f6e9cf31-f92d-478f-ab89-955835c23683',
#      'phone-number': '5104964687',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227462453',
#      '@type': 'phone',
#      'account-number': '449',
#      'device-id': '34703d51-ff43-4acb-bd9f-e10100da3841',
#      'phone-number': '9161654125',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227460449',
#      '@type': 'phone',
#      'account-number': '356',
#      'device-id': '94f908e5-ff2b-4661-b892-0d4110b290e3',
#      'phone-number': '4155612599',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227444381',
#      '@type': 'phone',
#      'account-number': '123',
#      'device-id': '425ffa78-f4da-49b1-8735-340afbdaca14',
#      'phone-number': '7075556653',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227432368',
#      '@type': 'phone',
#      'account-number': '467',
#      'device-id': '24966a23-9df0-4ef6-9813-469a54266548',
#      'phone-number': '4154428964',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227413006',
#      '@type': 'phone',
#      'account-number': '407',
#      'device-id': '2af5dd88-c6de-4f66-b0cb-536444bbf88f',
#      'phone-number': '6502784421',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227366193',
#      '@type': 'phone',
#      'account-number': '463',
#      'device-id': '6334f701-4fc0-481c-9c5e-33e26f29eb11',
#      'phone-number': '5103168445',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227352294',
#      '@type': 'phone',
#      'account-number': '429',
#      'device-id': '070e0ef1-dd8d-4a6f-8d00-70ba4ad450a5',
#      'phone-number': '5108860050',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227349216',
#      '@type': 'phone',
#      'account-number': '180',
#      'device-id': '7cd06085-e53d-4ef9-9a44-7be0a1f3fb08',
#      'phone-number': '5101190952',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227336876',
#      '@type': 'phone',
#      'account-number': '12528',
#      'device-id': '86a2f1ae-503f-4a35-9c19-324f238212c3',
#      'phone-number': '8187754640',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227306460',
#      '@type': 'phone',
#      'account-number': '382',
#      'device-id': 'be9a9b25-89d4-431a-b5ad-dd916b1148fd',
#      'phone-number': '4157383968',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227300540',
#      '@type': 'phone',
#      'account-number': '305',
#      'device-id': '82f7fd24-f481-4cd7-9fa9-783178c4b633',
#      'phone-number': '5103095729',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227281886',
#      '@type': 'phone',
#      'account-number': '293',
#      'device-id': 'c3dbe092-409c-4202-a2ef-59c0891a1a51',
#      'phone-number': '4159400192',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227268428',
#      '@type': 'phone',
#      'account-number': '55861',
#      'device-id': '35ae54fb-ac24-4c67-b412-723974e194b6',
#      'phone-number': '9517956606',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227241205',
#      '@type': 'phone',
#      'account-number': '6386',
#      'device-id': '5765680b-0631-434a-9a47-ff1c2ed02ef0',
#      'phone-number': '6618001716',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227215603',
#      '@type': 'phone',
#      'account-number': '79',
#      'device-id': '3809fda6-9db0-4b47-9800-ef07910221b3',
#      'phone-number': '5107606902',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227213573',
#      '@type': 'phone',
#      'account-number': '6',
#      'device-id': '7d11b8e3-d67d-45f9-b705-fbbbf16a0e02',
#      'phone-number': '9162111862',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227202172',
#      '@type': 'phone',
#      'account-number': '241',
#      'device-id': '4ae0824e-42a6-4aa1-89c8-243493a09f71',
#      'phone-number': '4155201906',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227192768',
#      '@type': 'phone',
#      'account-number': '107404',
#      'device-id': 'a34f5997-e02c-4ba1-a00f-9f408565c685',
#      'phone-number': '9512160493',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227187959',
#      '@type': 'phone',
#      'account-number': '350',
#      'device-id': '7f6102fc-8bd1-42eb-8144-ea1629847dc6',
#      'phone-number': '6505008683',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227179626',
#      '@type': 'phone',
#      'account-number': '375',
#      'device-id': 'a28234e2-3308-4444-a06a-205fa00d9c39',
#      'phone-number': '5105517777',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227176378',
#      '@type': 'phone',
#      'account-number': '14501',
#      'device-id': '0fd40479-9747-4104-86f0-7800541087d9',
#      'phone-number': '3102530687',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227173189',
#      '@type': 'phone',
#      'account-number': '59',
#      'device-id': '598f5e0d-db2b-4f28-aaa5-6a43159761de',
#      'phone-number': '5103147786',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227170543',
#      '@type': 'phone',
#      'account-number': '113',
#      'device-id': '35d3d77f-74bd-4f27-b428-1feaa3d0b11c',
#      'phone-number': '5100575073',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227129895',
#      '@type': 'phone',
#      'account-number': '135',
#      'device-id': '69a087c1-14bb-4fea-b40b-dfca0035f999',
#      'phone-number': '5109553651',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227108365',
#      '@type': 'phone',
#      'account-number': '28028',
#      'device-id': '61e44226-4dee-4b79-991b-c40b50e215ac',
#      'phone-number': '5103107438',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227106221',
#      '@type': 'phone',
#      'account-number': '432',
#      'device-id': 'df27313a-6ed2-43ac-aeb8-073a2e1b5a57',
#      'phone-number': '5107285542',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227105488',
#      '@type': 'phone',
#      'account-number': '403',
#      'device-id': '6303b0ea-bf39-4e34-bdf8-a1fe15de3027',
#      'phone-number': '4156669660',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227103092',
#      '@type': 'phone',
#      'account-number': '159',
#      'device-id': 'd89af7a3-6da5-4acb-b999-ff7f21e37f3b',
#      'phone-number': '6505892403',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227096692',
#      '@type': 'phone',
#      'account-number': '26001',
#      'device-id': '1fa1500d-e7b7-436b-a185-0789c6f2f42c',
#      'phone-number': '6572805809',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227083068',
#      '@type': 'phone',
#      'account-number': '68034',
#      'device-id': '85539f8e-2a88-4948-8912-ff1fc71047e0',
#      'phone-number': '9287870035',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227078349',
#      '@type': 'phone',
#      'account-number': '262',
#      'device-id': 'f1b3ecdb-7327-4c9b-8ddd-4083bd1e9c61',
#      'phone-number': '9161509342',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1227075700',
#      '@type': 'phone',
#      'account-number': '71',
#      'device-id': '566c8e28-1583-4772-89b4-47a3e66bee04',
#      'phone-number': '9160627649',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1227071165',
#      '@type': 'phone',
#      'account-number': '25',
#      'device-id': '4fc1d7ec-d0b7-4149-9899-e10aa0892c50',
#      'phone-number': '5106716204',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227061834',
#      '@type': 'phone',
#      'account-number': '29389',
#      'device-id': 'b8a7d48e-e5f6-42c8-8600-68f498d050a4',
#      'phone-number': '5039714527',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227047358',
#      '@type': 'phone',
#      'account-number': '123408',
#      'device-id': '9cb8b0d4-917b-4465-8024-f6c44ea944f4',
#      'phone-number': '9161495797',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1227006656',
#      '@type': 'phone',
#      'account-number': '215',
#      'device-id': '142fff48-c94b-4ff7-af7a-26a623b2c148',
#      'phone-number': '7073644115',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1227003406',
#      '@type': 'phone',
#      'account-number': '284',
#      'device-id': '5649d503-08a0-440d-a632-db739313f761',
#      'phone-number': '9166026450',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226962113',
#      '@type': 'phone',
#      'account-number': '223',
#      'device-id': '9407e003-e05a-438a-bcb4-7c74054ab870',
#      'phone-number': '6505293784',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1226954331',
#      '@type': 'phone',
#      'account-number': '44',
#      'device-id': '7c5c8c9b-db06-4bc9-8880-8b683a131c51',
#      'phone-number': '5102680691',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226932538',
#      '@type': 'phone',
#      'account-number': '72',
#      'device-id': '4baf9d0b-d32d-4887-bba9-93521564eb92',
#      'phone-number': '6509765463',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226925399',
#      '@type': 'phone',
#      'account-number': '134',
#      'device-id': 'b33ae619-9c6c-4223-99de-059ff1722ef2',
#      'phone-number': '5105155205',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226916311',
#      '@type': 'phone',
#      'account-number': '337',
#      'device-id': 'e0e4c76e-dea5-4dde-a5c1-395107750227',
#      'phone-number': '4159428403',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1226909219',
#      '@type': 'phone',
#      'account-number': '376',
#      'device-id': '86442bf9-76b7-4bae-a060-b68260636cba',
#      'phone-number': '9166411409',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226893551',
#      '@type': 'phone',
#      'account-number': '185',
#      'device-id': '1964df5f-8936-4928-9cd5-fbd5eaf4136e',
#      'phone-number': '7071779156',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1226889691',
#      '@type': 'phone',
#      'account-number': '207',
#      'device-id': '597a1c52-d120-49da-a03f-c9273edd1a4a',
#      'phone-number': '5107830293',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1226871468',
#      '@type': 'phone',
#      'account-number': '307',
#      'device-id': '78822b46-a072-4889-a5ae-06c632572c5e',
#      'phone-number': '7072884903',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226851411',
#      '@type': 'phone',
#      'account-number': '81',
#      'device-id': '34bd60bc-2f8c-4073-ac6b-65cced23b6e4',
#      'phone-number': '6503149681',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1226848084',
#      '@type': 'phone',
#      'account-number': '313',
#      'device-id': '93eb2d30-b700-4402-93d4-0e0ead5fd7cd',
#      'phone-number': '5103285924',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226830822',
#      '@type': 'phone',
#      'account-number': '386',
#      'device-id': 'e4f0f7ae-86f6-41af-8842-ca931488c672',
#      'phone-number': '7071257114',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226819166',
#      '@type': 'phone',
#      'account-number': '5',
#      'device-id': 'b72a7271-864e-46dc-b6bf-f5dd810f27ee',
#      'phone-number': '5107754354',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1226797238',
#      '@type': 'phone',
#      'account-number': '58552',
#      'device-id': '9e94d18e-4b97-45a0-a367-63bd1aeb5643',
#      'phone-number': '4152418283',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226796125',
#      '@type': 'phone',
#      'account-number': '112',
#      'device-id': 'bada37ea-8de7-4634-b705-d19b674b10dd',
#      'phone-number': '4150293906',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226793051',
#      '@type': 'phone',
#      'account-number': '99',
#      'device-id': '3aef4890-c93e-4972-a905-6cc3def1d19b',
#      'phone-number': '5102145517',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1226785810',
#      '@type': 'phone',
#      'account-number': '32',
#      'device-id': 'b3a6847c-c77d-4710-bfec-3eb3d991a15f',
#      'phone-number': '5108387425',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226780830',
#      '@type': 'phone',
#      'account-number': '139',
#      'device-id': '3e705bfa-2697-4690-af02-7ad9451c4f9c',
#      'phone-number': '6508780391',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1226780554',
#      '@type': 'phone',
#      'account-number': '48',
#      'device-id': '81a60aeb-0d08-4e54-9704-52740fd8a387',
#      'phone-number': '7078755344',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226778018',
#      '@type': 'phone',
#      'account-number': '2748',
#      'device-id': '20b7c339-847d-443b-b149-2f70b724e810',
#      'phone-number': '2095640777',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1226777227',
#      '@type': 'phone',
#      'account-number': '307',
#      'device-id': '516c6a73-7e08-47e1-a700-3ed97d9e9b5e',
#      'phone-number': '7072884903',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226764693',
#      '@type': 'phone',
#      'account-number': '1297',
#      'device-id': 'cac5ab39-a0fe-4d9d-a58c-eb9761e86a80',
#      'phone-number': '2092833894',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226763980',
#      '@type': 'phone',
#      'account-number': '26',
#      'device-id': '5c63c053-1c35-4170-8287-c6b027e6bd88',
#      'phone-number': '5101367449',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226762615',
#      '@type': 'phone',
#      'account-number': '359',
#      'device-id': 'b95942a1-90de-4786-b808-56c34ed0a28b',
#      'phone-number': '4151951455',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1226756930',
#      '@type': 'phone',
#      'account-number': '67',
#      'device-id': 'e3177e85-d0c9-401e-b553-2c4f06ab0967',
#      'phone-number': '5101032076',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1226749833',
#      '@type': 'phone',
#      'account-number': '366',
#      'device-id': '741f9ea9-73bc-4bc5-8d44-d1701bb3962e',
#      'phone-number': '5105723627',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226738474',
#      '@type': 'phone',
#      'account-number': '60954',
#      'device-id': '74318a1a-0fcc-4dd7-860c-6d5f05bafe90',
#      'phone-number': '9289510220',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1226709473',
#      '@type': 'phone',
#      'account-number': '58',
#      'device-id': '92fa28ab-9532-490c-8af0-7e2df769a3a9',
#      'phone-number': '6500393228',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226701950',
#      '@type': 'phone',
#      'account-number': '22',
#      'device-id': '99ac2986-d93c-4efc-913b-8b5be52aa1d5',
#      'phone-number': '5102858788',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226691746',
#      '@type': 'phone',
#      'account-number': '198',
#      'device-id': 'f719ef62-dbd3-4e8c-8e1a-0b68e6ad8b63',
#      'phone-number': '7078932972',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1226686607',
#      '@type': 'phone',
#      'account-number': '399',
#      'device-id': '676d7ae1-5e9d-441c-b638-514962388d76',
#      'phone-number': '5104255852',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226683325',
#      '@type': 'phone',
#      'account-number': '15',
#      'device-id': '76f2da6d-b1a3-45ef-9022-564c494e577b',
#      'phone-number': '5108428188',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1226683091',
#      '@type': 'phone',
#      'account-number': '20132',
#      'device-id': 'c6aa6562-2dfe-4b21-97ee-57530ea1ccfa',
#      'phone-number': '7026728206',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1226681383',
#      '@type': 'phone',
#      'account-number': '187',
#      'device-id': '0a5b7989-f95d-4bb1-a041-d8c09e7377eb',
#      'phone-number': '4152861127',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1226673056',
#      '@type': 'phone',
#      'account-number': '77',
#      'device-id': '0df68239-cbfb-4a4b-91ea-4fb016e8a90d',
#      'phone-number': '4158623685',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1226671661',
#      '@type': 'phone',
#      'account-number': '69',
#      'device-id': 'ae85e5a4-3907-4eba-8e87-d917dc10f75c',
#      'phone-number': '6501143930',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226671206',
#      '@type': 'phone',
#      'account-number': '427',
#      'device-id': '32256bae-b495-4bfc-b84f-4701d9f14b84',
#      'phone-number': '5109657043',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226664086',
#      '@type': 'phone',
#      'account-number': '59690',
#      'device-id': '00d22746-31d0-44f9-ab35-afe489ed0ebd',
#      'phone-number': '9284251886',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226663330',
#      '@type': 'phone',
#      'account-number': '93',
#      'device-id': '38eb1692-ae73-41da-a44b-a54bc7b5fcd7',
#      'phone-number': '4151631986',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1226659780',
#      '@type': 'phone',
#      'account-number': '365',
#      'device-id': '9793666e-8ebf-44b3-8fb5-f091b69d248a',
#      'phone-number': '4154589394',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226648453',
#      '@type': 'phone',
#      'account-number': '19',
#      'device-id': '80481be6-a76b-4303-9ec1-0dd437d64af7',
#      'phone-number': '7070013038',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226648345',
#      '@type': 'phone',
#      'account-number': '11036',
#      'device-id': 'dc05b2a4-ff2f-4341-9668-5e92cb443fd7',
#      'phone-number': '5596126490',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226642674',
#      '@type': 'phone',
#      'account-number': '228',
#      'device-id': '7965e62f-69f0-4ca2-8715-450439b8f894',
#      'phone-number': '7079548081',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1226617254',
#      '@type': 'phone',
#      'account-number': '163',
#      'device-id': '29b77ba9-b33f-46e1-8c38-6c8ed3b2eb7f',
#      'phone-number': '5101691548',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1226614688',
#      '@type': 'phone',
#      'account-number': '115',
#      'device-id': 'e6da1951-d219-4d13-9fe0-15f52cd809da',
#      'phone-number': '5104207058',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1226580160',
#      '@type': 'phone',
#      'account-number': '232',
#      'device-id': '92211cce-98c9-4431-b2b7-784d9ac8c595',
#      'phone-number': '7070880122',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226569940',
#      '@type': 'phone',
#      'account-number': '172',
#      'device-id': 'd4f4fb01-0a3e-4204-a3c9-2ba6db057aab',
#      'phone-number': '6501120813',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226567178',
#      '@type': 'phone',
#      'account-number': '227',
#      'device-id': 'ca9f3028-29c8-45d3-a772-94f6fc85e428',
#      'phone-number': '6505304437',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226566444',
#      '@type': 'phone',
#      'account-number': '416',
#      'device-id': 'e4477dd5-6a56-4212-bebc-3b777902f236',
#      'phone-number': '9161891477',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226563714',
# ...
#      'device-id': 'abd4c8f2-0826-4086-b8ef-3d3091cd81bb',
#      'phone-number': '6504123769',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1226070347',
#      '@type': 'phone',
#      'account-number': '294',
#      'device-id': '8d15e50b-fa8c-4e8b-b64f-aa0623f46774',
#      'phone-number': '6502001026',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1226068607',
#      '@type': 'phone',
#      'account-number': '1055',
#      'device-id': 'f52612d8-8f20-4e08-9b25-36fd0a127128',
#      'phone-number': '5108647878',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226054759',
#      '@type': 'phone',
#      'account-number': '64',
#      'device-id': '27c42d82-e80f-48f0-9128-d6daecb51e62',
#      'phone-number': '5102689749',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1226053047',
#      '@type': 'phone',
#      'account-number': '315',
#      'device-id': '0b3bd672-0359-4579-83e3-1e5da3d0c1cf',
#      'phone-number': '9167212066',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226046715',
#      '@type': 'phone',
#      'account-number': '259',
#      'device-id': 'd12103ad-1357-4f46-aa6c-abf97b5650e4',
#      'phone-number': '5100845932',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1226039107',
#      '@type': 'phone',
#      'account-number': '122',
#      'device-id': '0349b72c-9db9-4075-8232-0203ea2fa787',
#      'phone-number': '5109441371',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1226038286',
#      '@type': 'phone',
#      'account-number': '387',
#      'device-id': '85b17392-3d8e-406e-bb8b-52114d25d730',
#      'phone-number': '7073839638',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1226023227',
#      '@type': 'phone',
#      'account-number': '211',
#      'device-id': 'a719fd7a-815d-4ebc-812a-38e1b070e02e',
#      'phone-number': '7079726497',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1226010573',
#      '@type': 'phone',
#      'account-number': '107180',
#      'device-id': '9cf9e6a2-7413-4ec0-a0ef-471d325bf1c4',
#      'phone-number': '4080170748',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1226002218',
#      '@type': 'phone',
#      'account-number': '50876',
#      'device-id': '3bcab81b-48d3-4099-be1c-ab4bcfd24959',
#      'phone-number': '6265924615',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225995937',
#      '@type': 'phone',
#      'account-number': '54084',
#      'device-id': '98e323b0-baf8-403a-ba17-21169f90cf1e',
#      'phone-number': '8187200809',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225994818',
#      '@type': 'phone',
#      'account-number': '368',
#      'device-id': 'b394c845-065b-4a91-a261-d8de81d653aa',
#      'phone-number': '5108104669',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225993483',
#      '@type': 'phone',
#      'account-number': '231',
#      'device-id': 'c759fab6-38c5-416f-9293-62c03ce6bc86',
#      'phone-number': '4150983324',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225984043',
#      '@type': 'phone',
#      'account-number': '16907',
#      'device-id': 'f3f64cb0-db9b-49ae-9037-31867ae81bae',
#      'phone-number': '5624167437',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225979086',
#      '@type': 'phone',
#      'account-number': '97',
#      'device-id': 'a899a82b-3e5e-4b5a-b1c9-c97e672832fa',
#      'phone-number': '5102439375',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225963218',
#      '@type': 'phone',
#      'account-number': '243',
#      'device-id': '15782d47-26d5-4cdd-98ad-149943eedcba',
#      'phone-number': '6505061680',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225930843',
#      '@type': 'phone',
#      'account-number': '417',
#      'device-id': '2bace1d1-7c02-4532-8ad3-6b88b56ee9ec',
#      'phone-number': '4156254158',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225924381',
#      '@type': 'phone',
#      'account-number': '251',
#      'device-id': 'c6cc51fb-2142-4d61-a490-1de24eee0ee9',
#      'phone-number': '6505597078',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225917470',
#      '@type': 'phone',
#      'account-number': '102',
#      'device-id': 'd69a813f-8d3f-45e0-b0a7-085c780f8fac',
#      'phone-number': '5102393293',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225912561',
#      '@type': 'phone',
#      'account-number': '18',
#      'device-id': 'e7487a33-911c-40f9-a43c-86277c641879',
#      'phone-number': '6506033983',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225909491',
#      '@type': 'phone',
#      'account-number': '254',
#      'device-id': 'a95049c9-a338-402b-93c2-4c8c56f7ee7c',
#      'phone-number': '4156978598',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225903244',
#      '@type': 'phone',
#      'account-number': '118329',
#      'device-id': '33b16389-d814-4e18-8f72-1f3884bd5f64',
#      'phone-number': '5414036682',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225875775',
#      '@type': 'phone',
#      'account-number': '47',
#      'device-id': 'f0cd06c6-af21-4344-89c7-aa802e2a8011',
#      'phone-number': '5106329832',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225861542',
#      '@type': 'phone',
#      'account-number': '206',
#      'device-id': '494dadd7-ccff-49e5-8653-16ccbaae3ebf',
#      'phone-number': '5107385381',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225860989',
#      '@type': 'phone',
#      'account-number': '162',
#      'device-id': '9b9671bc-9af0-44cc-99d4-cd38fd35c609',
#      'phone-number': '5107380008',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225851138',
#      '@type': 'phone',
#      'account-number': '273',
#      'device-id': '97c8d28e-ef21-4487-9587-fe739cf6e101',
#      'phone-number': '5104066441',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225820175',
#      '@type': 'phone',
#      'account-number': '352',
#      'device-id': 'cc4cdc54-c135-415d-b085-763f21b35730',
#      'phone-number': '4152732908',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225819365',
#      '@type': 'phone',
#      'account-number': '267',
#      'device-id': 'c7fa6e19-3f7f-4f4b-abf2-02683b2e82f9',
#      'phone-number': '9169252484',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225817792',
#      '@type': 'phone',
#      'account-number': '274',
#      'device-id': '7de27b2f-18bd-410f-8f0b-194e2a98bdbe',
#      'phone-number': '5102866680',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225811266',
#      '@type': 'phone',
#      'account-number': '430',
#      'device-id': '8cffad95-3fd0-4c02-8be2-346bcd27f631',
#      'phone-number': '5102654195',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225803113',
#      '@type': 'phone',
#      'account-number': '816',
#      'device-id': 'c21c33ac-1191-4537-a78f-3438d2416949',
#      'phone-number': '9160228886',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225780486',
#      '@type': 'phone',
#      'account-number': '466',
#      'device-id': '5c0f57cc-78fe-47a4-ae2f-712508bdb416',
#      'phone-number': '5100225594',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225777069',
#      '@type': 'phone',
#      'account-number': '224',
#      'device-id': '95a5492c-7b56-4256-b95d-c82f75867217',
#      'phone-number': '5108762113',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225772409',
#      '@type': 'phone',
#      'account-number': '421',
#      'device-id': '82ca09a5-6c66-4639-ad78-419355589d9f',
#      'phone-number': '7072912797',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225770080',
#      '@type': 'phone',
#      'account-number': '21337',
#      'device-id': '8c8a1155-dcfb-4253-846f-a369d69a4c11',
#      'phone-number': '8183556078',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225766882',
#      '@type': 'phone',
#      'account-number': '329',
#      'device-id': '89c491b1-1dbf-42eb-a9b7-51b378b8af72',
#      'phone-number': '6505755572',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225762527',
#      '@type': 'phone',
#      'account-number': '478',
#      'device-id': 'fe031e8e-f998-4624-9c74-5d27ac53d3ab',
#      'phone-number': '7079435879',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225753656',
#      '@type': 'phone',
#      'account-number': '432',
#      'device-id': '5fa0eebd-8648-482c-839a-7cd9ebe95b71',
#      'phone-number': '5107285542',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225751275',
#      '@type': 'phone',
#      'account-number': '170',
#      'device-id': '783af6a7-6475-4c74-b327-4672247a3549',
#      'phone-number': '9167863246',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225746212',
#      '@type': 'phone',
#      'account-number': '391',
#      'device-id': '402f16a7-b65c-45c7-afe2-e573bcaead8c',
#      'phone-number': '6501569040',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225742879',
#      '@type': 'phone',
#      'account-number': '109',
#      'device-id': 'c6e1d63e-2518-48f7-b28f-a7413729c98f',
#      'phone-number': '7079737340',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225732684',
#      '@type': 'phone',
#      'account-number': '287',
#      'device-id': 'ec1bbfdb-11a5-408b-b747-202c99211f0f',
#      'phone-number': '9169106818',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225731179',
#      '@type': 'phone',
#      'account-number': '86',
#      'device-id': 'dadd3e5a-d3ba-46bc-b30f-5ab78b37c4d9',
#      'phone-number': '5106698545',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225730773',
#      '@type': 'phone',
#      'account-number': '140',
#      'device-id': 'ffd6d3de-ec18-410a-8d62-8aaea087cc49',
#      'phone-number': '4154577235',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225729029',
#      '@type': 'phone',
#      'account-number': '446',
#      'device-id': 'f5bcdf73-64fb-43f9-8c17-d06be8bc6365',
#      'phone-number': '5102926102',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225712341',
#      '@type': 'phone',
#      'account-number': '12803',
#      'device-id': '6e079507-a217-42aa-b85f-5035e210b786',
#      'phone-number': '4245093328',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225696578',
#      '@type': 'phone',
#      'account-number': '443',
#      'device-id': '3fe47112-a956-46d0-88a8-600ac7ab949f',
#      'phone-number': '5105377753',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225683016',
#      '@type': 'phone',
#      'account-number': '456',
#      'device-id': '78853763-cdd7-4e5f-9227-4544cb865711',
#      'phone-number': '5109807377',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225677680',
#      '@type': 'phone',
#      'account-number': '381',
#      'device-id': '7c70dc79-d33c-4a78-b440-c05b5b011037',
#      'phone-number': '4153365303',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225676641',
#      '@type': 'phone',
#      'account-number': '98',
#      'device-id': '57f5315e-2975-4c3e-93ba-ff04a1f2e8ac',
#      'phone-number': '5103197687',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225675890',
#      '@type': 'phone',
#      'account-number': '362',
#      'device-id': '5979526a-6f45-4339-ab3f-ea494d36556f',
#      'phone-number': '4159253838',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225672491',
#      '@type': 'phone',
#      'account-number': '246',
#      'device-id': 'cc3afbc4-fde7-465d-99a9-b1390dbef73c',
#      'phone-number': '5109530656',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225670934',
#      '@type': 'phone',
#      'account-number': '29609',
#      'device-id': '5d274380-1baf-49a1-b79f-6beea7a26e8f',
#      'phone-number': '5106050290',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225669984',
#      '@type': 'phone',
#      'account-number': '68',
#      'device-id': '94e3daa4-0331-489e-b182-99785acb0c50',
#      'phone-number': '5102984254',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225666507',
#      '@type': 'phone',
#      'account-number': '218',
#      'device-id': '77d7f474-7075-472b-a71b-55e2e42a6956',
#      'phone-number': '7076585071',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225647825',
#      '@type': 'phone',
#      'account-number': '173',
#      'device-id': 'ce6ac725-3868-417d-9fe1-645e905c8fb8',
#      'phone-number': '5109427954',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225641325',
#      '@type': 'phone',
#      'account-number': '20',
#      'device-id': 'f88e538f-e4b9-4395-8f06-219f187ec34e',
#      'phone-number': '7075831640',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225633957',
#      '@type': 'phone',
#      'account-number': '127',
#      'device-id': 'ff993835-f44b-48c9-9f06-6ecedf2962cc',
#      'phone-number': '7077814054',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225627855',
#      '@type': 'phone',
#      'account-number': '358',
#      'device-id': '34e559f9-953a-4efb-bfde-bb9cb6a3d908',
#      'phone-number': '9168169852',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225626120',
#      '@type': 'phone',
#      'account-number': '111',
#      'device-id': '96da7e9f-50a7-4518-82d1-5a7ddf2e07f4',
#      'phone-number': '5108252790',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225610504',
#      '@type': 'phone',
#      'account-number': '190',
#      'device-id': '44ee9903-241d-4363-b267-610d5db0b3aa',
#      'phone-number': '5105126542',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225597092',
#      '@type': 'phone',
#      'account-number': '453',
#      'device-id': '9280d946-b2de-4e9f-8657-dbb234b1e2a4',
#      'phone-number': '7073559747',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225578485',
#      '@type': 'phone',
#      'account-number': '160',
#      'device-id': '1aad9107-83a5-4047-8f7f-6ab416a32bee',
#      'phone-number': '4158441466',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225570113',
#      '@type': 'phone',
#      'account-number': '367',
#      'device-id': 'c2361109-6f4f-4e96-9c2f-53496ca34f59',
#      'phone-number': '9168238433',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225568764',
#      '@type': 'phone',
#      'account-number': '169',
#      'device-id': '838f6857-f3c6-4d38-95e4-3557f6f2128a',
#      'phone-number': '7075173347',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225564434',
#      '@type': 'phone',
#      'account-number': '150',
#      'device-id': '7b15d752-5e69-4292-b818-c7c2f196c78b',
#      'phone-number': '5102799018',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225562113',
#      '@type': 'phone',
#      'account-number': '34',
#      'device-id': 'c719a38a-2292-47bb-aa5e-711f678e616f',
#      'phone-number': '5109458176',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225557123',
#      '@type': 'phone',
#      'account-number': '308',
#      'device-id': '6986b267-0c34-44af-9f24-646d46fa3bf4',
#      'phone-number': '7075382511',
#      'model': 'Sorrento F00L'},
#     {'@timestamp': '1225546475',
#      '@type': 'phone',
#      'account-number': '344',
#      'device-id': 'e17e1abd-2998-4f8e-9950-7ce4ac1f412a',
#      'phone-number': '4157994884',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225532588',
#      '@type': 'phone',
#      'account-number': '328',
#      'device-id': 'd5910942-e9c0-46df-b3f2-93b12c068347',
#      'phone-number': '5104718508',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225521652',
#      '@type': 'phone',
#      'account-number': '341',
#      'device-id': 'bd49bdda-135b-4f93-af88-f07d39eed6ef',
#      'phone-number': '5107739396',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225515059',
#      '@type': 'phone',
#      'account-number': '192',
#      'device-id': '14278cd8-6239-45b1-a59a-b5d710af2bd0',
#      'phone-number': '9168053145',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225504008',
#      '@type': 'phone',
#      'account-number': '66',
#      'device-id': 'ed051262-392a-49ab-a627-3845d7d742d3',
#      'phone-number': '5101166999',
#      'model': 'Titanic 1000'},
#     {'@timestamp': '1225492440',
#      '@type': 'phone',
#      'account-number': '153',
#      'device-id': '4fa2d027-ae7d-4d8b-9ea3-42fe6214a9c8',
#      'phone-number': '5100978341',
#      'model': 'MeeToo 1.0'},
#     {'@timestamp': '1225488157',
#      '@type': 'phone',
#      'account-number': '25406',
#      'device-id': 'd0983035-7470-43a1-a94f-6e1ec8af6790',
#      'phone-number': '9096011974',
#      'model': 'iFruit 1'},
#     {'@timestamp': '1225487136',
#      '@type': 'phone',
#      'account-number': '348',
#      'device-id': '288b0949-e3cf-4ac2-8aad-2c4ec811ad07',
#      'phone-number': '7079223784',
#      'model': 'iFruit 1'}]}}]

# %%
myrdd3 = myrdd2.flatMap(lambda x: x['activations']['activation'])

# %%
myrdd3.count()
# Out:
# 194764

# %%
myrdd3.take(3)
# Out:
# [{'@timestamp': '1225462088',
#   '@type': 'phone',
#   'account-number': '9763',
#   'device-id': 'debea35e-3ecd-4ee7-b0dd-ad428d953f32',
#   'phone-number': '7600763387',
#   'model': 'MeeToo 1.0'},
#  {'@timestamp': '1225461447',
#   '@type': 'phone',
#   'account-number': '426',
#   'device-id': '38a1566d-524e-4137-bad8-b597d09b54b0',
#   'phone-number': '5102521038',
#   'model': 'Titanic 1000'},
#  {'@timestamp': '1225446947',
#   '@type': 'phone',
#   'account-number': '383',
#   'device-id': '513024a3-a828-4674-9ff6-041e9a851f18',
#   'phone-number': '9162206560',
#   'model': 'Sorrento F00L'}]

# %%
myrdd4 = myrdd3.map(lambda x: x["account-number"] + ":" + x["model"])

# %%
myrdd4.take(10)
# Out:
# ['9763:MeeToo 1.0',
#  '426:Titanic 1000',
#  '383:Sorrento F00L',
#  '404:MeeToo 1.0',
#  '393:iFruit 1',
#  '53:MeeToo 1.0',
#  '96:iFruit 1',
#  '283:Sorrento F00L',
#  '464:MeeToo 1.0',
#  '475:Titanic 1000']

# %%
myrdd4.saveAsTextFile('/FileStore/tables/account-models')

# %%
dbutils.fs.ls('FileStore/tables/account-models')
# Out:
# [FileInfo(path='dbfs:/FileStore/tables/account-models/_SUCCESS', name='_SUCCESS', size=0, modificationTime=1739557934000),
#  FileInfo(path='dbfs:/FileStore/tables/account-models/part-00000', name='part-00000', size=1858986, modificationTime=1739557934000),
#  FileInfo(path='dbfs:/FileStore/tables/account-models/part-00001', name='part-00001', size=1885226, modificationTime=1739557930000)]

# %%
fileroot = "accounts"
dbutils.fs.cp('FileStore/tables/' + fileroot + '.zip', 'file:/tmp/')
# Out:
# True

# %%
import os
os.environ['fileroot'] = fileroot

# %%
# %sh

unzip -d /tmp /tmp/$fileroot.zip
# Out:
# Archive:  /tmp/accounts.zip
#    creating: /tmp/accounts/
#   inflating: /tmp/accounts/part-m-00004
#   inflating: /tmp/accounts/part-m-00006
#   inflating: /tmp/accounts/part-m-00001
#   inflating: /tmp/accounts/part-m-00003
#   inflating: /tmp/accounts/part-m-00005
#   inflating: /tmp/accounts/part-m-00000
#   inflating: /tmp/accounts/part-m-00002

# %%
dbutils.fs.mkdirs("/FileStore/tables/" + fileroot)
# Out:
# True

# %%
dbutils.fs.mv("file:/tmp/" + fileroot , "/FileStore/tables/" + fileroot , True)
# Out:
# True

# %%
dbutils.fs.ls('/FileStore/tables/logs')
# Out:
# [FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-15.log', name='2013-09-15.log', size=521343, modificationTime=1738175261000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-16.log', name='2013-09-16.log', size=484079, modificationTime=1738175292000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-17.log', name='2013-09-17.log', size=527399, modificationTime=1738175287000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-18.log', name='2013-09-18.log', size=485105, modificationTime=1738175256000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-19.log', name='2013-09-19.log', size=508553, modificationTime=1738175285000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-20.log', name='2013-09-20.log', size=492134, modificationTime=1738175288000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-21.log', name='2013-09-21.log', size=489117, modificationTime=1738175253000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-22.log', name='2013-09-22.log', size=535780, modificationTime=1738175286000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-23.log', name='2013-09-23.log', size=501768, modificationTime=1738175274000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-24.log', name='2013-09-24.log', size=489344, modificationTime=1738175260000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-25.log', name='2013-09-25.log', size=487857, modificationTime=1738175267000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-26.log', name='2013-09-26.log', size=523186, modificationTime=1738175268000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-27.log', name='2013-09-27.log', size=506195, modificationTime=1738175291000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-28.log', name='2013-09-28.log', size=492600, modificationTime=1738175283000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-29.log', name='2013-09-29.log', size=481479, modificationTime=1738175275000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-09-30.log', name='2013-09-30.log', size=525367, modificationTime=1738175292000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-01.log', name='2013-10-01.log', size=484920, modificationTime=1738175272000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-02.log', name='2013-10-02.log', size=527452, modificationTime=1738175262000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-03.log', name='2013-10-03.log', size=521262, modificationTime=1738175252000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-04.log', name='2013-10-04.log', size=498950, modificationTime=1738175260000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-05.log', name='2013-10-05.log', size=510510, modificationTime=1738175254000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-06.log', name='2013-10-06.log', size=489554, modificationTime=1738175250000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-07.log', name='2013-10-07.log', size=489616, modificationTime=1738175268000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-08.log', name='2013-10-08.log', size=523298, modificationTime=1738175255000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-09.log', name='2013-10-09.log', size=529434, modificationTime=1738175258000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-10.log', name='2013-10-10.log', size=521604, modificationTime=1738175290000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-11.log', name='2013-10-11.log', size=524138, modificationTime=1738175252000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-12.log', name='2013-10-12.log', size=517782, modificationTime=1738175268000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-13.log', name='2013-10-13.log', size=522873, modificationTime=1738175277000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-14.log', name='2013-10-14.log', size=496593, modificationTime=1738175287000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-15.log', name='2013-10-15.log', size=495224, modificationTime=1738175247000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-16.log', name='2013-10-16.log', size=521024, modificationTime=1738175263000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-17.log', name='2013-10-17.log', size=500818, modificationTime=1738175292000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-18.log', name='2013-10-18.log', size=501154, modificationTime=1738175290000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-19.log', name='2013-10-19.log', size=527543, modificationTime=1738175253000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-20.log', name='2013-10-20.log', size=518589, modificationTime=1738175281000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-21.log', name='2013-10-21.log', size=512893, modificationTime=1738175278000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-22.log', name='2013-10-22.log', size=518030, modificationTime=1738175260000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-23.log', name='2013-10-23.log', size=492463, modificationTime=1738175282000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-24.log', name='2013-10-24.log', size=492054, modificationTime=1738175285000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-25.log', name='2013-10-25.log', size=533207, modificationTime=1738175288000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-26.log', name='2013-10-26.log', size=503777, modificationTime=1738175267000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-27.log', name='2013-10-27.log', size=503420, modificationTime=1738175248000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-28.log', name='2013-10-28.log', size=524048, modificationTime=1738175276000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-29.log', name='2013-10-29.log', size=510800, modificationTime=1738175271000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-30.log', name='2013-10-30.log', size=523180, modificationTime=1738175249000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-10-31.log', name='2013-10-31.log', size=524277, modificationTime=1738175249000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-01.log', name='2013-11-01.log', size=969586, modificationTime=1738175248000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-02.log', name='2013-11-02.log', size=1061868, modificationTime=1738175268000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-03.log', name='2013-11-03.log', size=1093742, modificationTime=1738175282000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-04.log', name='2013-11-04.log', size=956153, modificationTime=1738175247000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-05.log', name='2013-11-05.log', size=1085429, modificationTime=1738175248000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-06.log', name='2013-11-06.log', size=1071334, modificationTime=1738175263000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-07.log', name='2013-11-07.log', size=1038115, modificationTime=1738175251000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-08.log', name='2013-11-08.log', size=1078367, modificationTime=1738175285000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-09.log', name='2013-11-09.log', size=970029, modificationTime=1738175254000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-10.log', name='2013-11-10.log', size=1095755, modificationTime=1738175269000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-11.log', name='2013-11-11.log', size=977765, modificationTime=1738175273000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-12.log', name='2013-11-12.log', size=970149, modificationTime=1738175276000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-13.log', name='2013-11-13.log', size=1039116, modificationTime=1738175291000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-14.log', name='2013-11-14.log', size=1081771, modificationTime=1738175249000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-15.log', name='2013-11-15.log', size=982380, modificationTime=1738175291000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-16.log', name='2013-11-16.log', size=1009713, modificationTime=1738175270000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-17.log', name='2013-11-17.log', size=1086494, modificationTime=1738175274000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-18.log', name='2013-11-18.log', size=978348, modificationTime=1738175256000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-19.log', name='2013-11-19.log', size=1083789, modificationTime=1738175252000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-20.log', name='2013-11-20.log', size=1009470, modificationTime=1738175257000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-21.log', name='2013-11-21.log', size=1057086, modificationTime=1738175271000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-22.log', name='2013-11-22.log', size=975288, modificationTime=1738175253000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-23.log', name='2013-11-23.log', size=1063118, modificationTime=1738175279000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-24.log', name='2013-11-24.log', size=1048393, modificationTime=1738175273000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-25.log', name='2013-11-25.log', size=974776, modificationTime=1738175281000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-26.log', name='2013-11-26.log', size=962392, modificationTime=1738175291000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-27.log', name='2013-11-27.log', size=976234, modificationTime=1738175254000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-28.log', name='2013-11-28.log', size=976027, modificationTime=1738175286000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-29.log', name='2013-11-29.log', size=1081953, modificationTime=1738175279000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-11-30.log', name='2013-11-30.log', size=1006926, modificationTime=1738175264000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-01.log', name='2013-12-01.log', size=1014795, modificationTime=1738175275000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-02.log', name='2013-12-02.log', size=1093271, modificationTime=1738175278000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-03.log', name='2013-12-03.log', size=1068328, modificationTime=1738175246000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-04.log', name='2013-12-04.log', size=1070066, modificationTime=1738175262000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-05.log', name='2013-12-05.log', size=1028342, modificationTime=1738175283000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-06.log', name='2013-12-06.log', size=1031373, modificationTime=1738175266000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-07.log', name='2013-12-07.log', size=1018063, modificationTime=1738175287000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-08.log', name='2013-12-08.log', size=1039394, modificationTime=1738175261000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-09.log', name='2013-12-09.log', size=1101053, modificationTime=1738175283000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-10.log', name='2013-12-10.log', size=1009430, modificationTime=1738175278000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-11.log', name='2013-12-11.log', size=1061891, modificationTime=1738175269000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-12.log', name='2013-12-12.log', size=1030641, modificationTime=1738175276000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-13.log', name='2013-12-13.log', size=1028946, modificationTime=1738175257000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-14.log', name='2013-12-14.log', size=985819, modificationTime=1738175265000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-15.log', name='2013-12-15.log', size=1080787, modificationTime=1738175252000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-16.log', name='2013-12-16.log', size=1004498, modificationTime=1738175287000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-17.log', name='2013-12-17.log', size=1078566, modificationTime=1738175255000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-18.log', name='2013-12-18.log', size=1069630, modificationTime=1738175282000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-19.log', name='2013-12-19.log', size=1050695, modificationTime=1738175265000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-20.log', name='2013-12-20.log', size=1108042, modificationTime=1738175272000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-21.log', name='2013-12-21.log', size=986692, modificationTime=1738175284000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-22.log', name='2013-12-22.log', size=1045723, modificationTime=1738175259000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-23.log', name='2013-12-23.log', size=990531, modificationTime=1738175263000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-24.log', name='2013-12-24.log', size=1059352, modificationTime=1738175285000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-25.log', name='2013-12-25.log', size=980457, modificationTime=1738175279000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-26.log', name='2013-12-26.log', size=1054182, modificationTime=1738175250000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-27.log', name='2013-12-27.log', size=1017134, modificationTime=1738175257000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-28.log', name='2013-12-28.log', size=1064484, modificationTime=1738175283000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-29.log', name='2013-12-29.log', size=1022151, modificationTime=1738175277000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-30.log', name='2013-12-30.log', size=1070391, modificationTime=1738175288000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2013-12-31.log', name='2013-12-31.log', size=992528, modificationTime=1738175247000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-01.log', name='2014-01-01.log', size=1057534, modificationTime=1738175259000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-02.log', name='2014-01-02.log', size=1053566, modificationTime=1738175270000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-03.log', name='2014-01-03.log', size=981998, modificationTime=1738175265000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-04.log', name='2014-01-04.log', size=1100898, modificationTime=1738175269000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-05.log', name='2014-01-05.log', size=1012644, modificationTime=1738175259000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-06.log', name='2014-01-06.log', size=1094868, modificationTime=1738175263000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-07.log', name='2014-01-07.log', size=1094753, modificationTime=1738175292000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-08.log', name='2014-01-08.log', size=1037422, modificationTime=1738175289000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-09.log', name='2014-01-09.log', size=1032385, modificationTime=1738175281000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-10.log', name='2014-01-10.log', size=977679, modificationTime=1738175288000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-11.log', name='2014-01-11.log', size=993697, modificationTime=1738175266000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-12.log', name='2014-01-12.log', size=1073307, modificationTime=1738175247000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-13.log', name='2014-01-13.log', size=1048789, modificationTime=1738175291000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-14.log', name='2014-01-14.log', size=1001350, modificationTime=1738175271000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-15.log', name='2014-01-15.log', size=1048617, modificationTime=1738175290000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-16.log', name='2014-01-16.log', size=996816, modificationTime=1738175264000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-17.log', name='2014-01-17.log', size=1044827, modificationTime=1738175246000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-18.log', name='2014-01-18.log', size=972872, modificationTime=1738175266000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-19.log', name='2014-01-19.log', size=975136, modificationTime=1738175279000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-20.log', name='2014-01-20.log', size=1020891, modificationTime=1738175265000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-21.log', name='2014-01-21.log', size=1011424, modificationTime=1738175289000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-22.log', name='2014-01-22.log', size=1109304, modificationTime=1738175273000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-23.log', name='2014-01-23.log', size=976011, modificationTime=1738175250000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-24.log', name='2014-01-24.log', size=1061764, modificationTime=1738175259000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-25.log', name='2014-01-25.log', size=1072204, modificationTime=1738175262000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-26.log', name='2014-01-26.log', size=1065979, modificationTime=1738175268000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-27.log', name='2014-01-27.log', size=1096363, modificationTime=1738175264000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-28.log', name='2014-01-28.log', size=1083865, modificationTime=1738175259000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-29.log', name='2014-01-29.log', size=1012968, modificationTime=1738175255000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-30.log', name='2014-01-30.log', size=1081064, modificationTime=1738175278000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-01-31.log', name='2014-01-31.log', size=1101529, modificationTime=1738175258000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-01.log', name='2014-02-01.log', size=1053099, modificationTime=1738175284000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-02.log', name='2014-02-02.log', size=1067044, modificationTime=1738175280000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-03.log', name='2014-02-03.log', size=1003003, modificationTime=1738175254000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-04.log', name='2014-02-04.log', size=1017259, modificationTime=1738175257000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-05.log', name='2014-02-05.log', size=1005783, modificationTime=1738175270000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-06.log', name='2014-02-06.log', size=1065257, modificationTime=1738175248000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-07.log', name='2014-02-07.log', size=996107, modificationTime=1738175277000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-08.log', name='2014-02-08.log', size=1035289, modificationTime=1738175290000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-09.log', name='2014-02-09.log', size=1065078, modificationTime=1738175288000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-10.log', name='2014-02-10.log', size=1044403, modificationTime=1738175261000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-11.log', name='2014-02-11.log', size=1057235, modificationTime=1738175271000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-12.log', name='2014-02-12.log', size=1091711, modificationTime=1738175267000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-13.log', name='2014-02-13.log', size=1096726, modificationTime=1738175286000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-14.log', name='2014-02-14.log', size=1072065, modificationTime=1738175273000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-15.log', name='2014-02-15.log', size=1010563, modificationTime=1738175256000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-16.log', name='2014-02-16.log', size=1056078, modificationTime=1738175252000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-17.log', name='2014-02-17.log', size=994481, modificationTime=1738175251000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-18.log', name='2014-02-18.log', size=1019882, modificationTime=1738175281000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-19.log', name='2014-02-19.log', size=992774, modificationTime=1738175261000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-20.log', name='2014-02-20.log', size=992721, modificationTime=1738175260000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-21.log', name='2014-02-21.log', size=1024612, modificationTime=1738175277000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-22.log', name='2014-02-22.log', size=1060506, modificationTime=1738175274000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-23.log', name='2014-02-23.log', size=1017947, modificationTime=1738175282000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-24.log', name='2014-02-24.log', size=1104389, modificationTime=1738175270000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-25.log', name='2014-02-25.log', size=1018667, modificationTime=1738175280000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-26.log', name='2014-02-26.log', size=1076821, modificationTime=1738175250000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-27.log', name='2014-02-27.log', size=1090745, modificationTime=1738175280000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-02-28.log', name='2014-02-28.log', size=975382, modificationTime=1738175246000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-03-01.log', name='2014-03-01.log', size=1004630, modificationTime=1738175249000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-03-02.log', name='2014-03-02.log', size=1005688, modificationTime=1738175258000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-03-03.log', name='2014-03-03.log', size=981270, modificationTime=1738175274000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-03-04.log', name='2014-03-04.log', size=968023, modificationTime=1738175272000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-03-05.log', name='2014-03-05.log', size=1006960, modificationTime=1738175289000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-03-06.log', name='2014-03-06.log', size=1014931, modificationTime=1738175253000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-03-07.log', name='2014-03-07.log', size=1103088, modificationTime=1738175251000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-03-08.log', name='2014-03-08.log', size=1001566, modificationTime=1738175275000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-03-09.log', name='2014-03-09.log', size=995517, modificationTime=1738175272000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-03-10.log', name='2014-03-10.log', size=1091560, modificationTime=1738175275000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-03-11.log', name='2014-03-11.log', size=1038692, modificationTime=1738175256000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-03-12.log', name='2014-03-12.log', size=1047117, modificationTime=1738175286000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-03-13.log', name='2014-03-13.log', size=997473, modificationTime=1738175251000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-03-14.log', name='2014-03-14.log', size=994147, modificationTime=1738175284000),
#  FileInfo(path='dbfs:/FileStore/tables/logs/2014-03-15.log', name='2014-03-15.log', size=1074872, modificationTime=1738175267000)]

# %%
dbutils.fs.head('/FileStore/tables/logs/2013-09-15.log')
# Out:
# [Truncated to first 65536 bytes]
# '3.94.78.5 - 69827 [15/Sep/2013:23:58:36 +0100] "GET /KBDOC-00033.html HTTP/1.0" 200 14417 "http://www.loudacre.com"  "Loudacre Mobile Browser iFruit 1"\n3.94.78.5 - 69827 [15/Sep/2013:23:58:36 +0100] "GET /theme.css HTTP/1.0" 200 3576 "http://www.loudacre.com"  "Loudacre Mobile Browser iFruit 1"\n19.38.140.62 - 21475 [15/Sep/2013:23:58:34 +0100] "GET /KBDOC-00277.html HTTP/1.0" 200 15517 "http://www.loudacre.com"  "Loudacre Mobile Browser Ronin S1"\n19.38.140.62 - 21475 [15/Sep/2013:23:58:34 +0100] "GET /theme.css HTTP/1.0" 200 13353 "http://www.loudacre.com"  "Loudacre Mobile Browser Ronin S1"\n129.133.56.105 - 2489 [15/Sep/2013:23:58:34 +0100] "GET /KBDOC-00033.html HTTP/1.0" 200 10590 "http://www.loudacre.com"  "Loudacre Mobile Browser Sorrento F00L"\n129.133.56.105 - 2489 [15/Sep/2013:23:58:34 +0100] "GET /theme.css HTTP/1.0" 200 12295 "http://www.loudacre.com"  "Loudacre Mobile Browser Sorrento F00L"\n217.150.149.167 - 4712 [15/Sep/2013:23:56:06 +0100] "GET /ronin_s4_sales.html HTTP/1.0" 200 845 "http://www.loudacre.com"  "Loudacre Mobile Browser MeeToo 1.0"\n217.150.149.167 - 4712 [15/Sep/2013:23:56:06 +0100] "GET /theme.css HTTP/1.0" 200 738 "http://www.loudacre.com"  "Loudacre Mobile Browser MeeToo 1.0"\n217.150.149.167 - 4712 [15/Sep/2013:23:56:06 +0100] "GET /code.js HTTP/1.0" 200 938 "http://www.loudacre.com"  "Loudacre Mobile Browser MeeToo 1.0"\n217.150.149.167 - 4712 [15/Sep/2013:23:56:06 +0100] "GET /ronin_s4.jpg HTTP/1.0" 200 5552 "http://www.loudacre.com"  "Loudacre Mobile Browser MeeToo 1.0"\n209.151.12.34 - 45922 [15/Sep/2013:23:55:09 +0100] "GET /KBDOC-00259.html HTTP/1.0" 200 19362 "http://www.loudacre.com"  "Loudacre Mobile Browser Sorrento F11L"\n209.151.12.34 - 45922 [15/Sep/2013:23:55:09 +0100] "GET /theme.css HTTP/1.0" 200 17795 "http://www.loudacre.com"  "Loudacre Mobile Browser Sorrento F11L"\n184.97.84.245 - 144 [15/Sep/2013:23:54:55 +0100] "GET /KBDOC-00052.html HTTP/1.0" 200 12499 "http://www.loudacre.com"  "Loudacre CSR Browser"\n184.97.84.245 - 144 [15/Sep/2013:23:54:55 +0100] "GET /theme.css HTTP/1.0" 200 4979 "http://www.loudacre.com"  "Loudacre CSR Browser"\n233.60.251.2 - 33908 [15/Sep/2013:23:51:43 +0100] "GET /KBDOC-00292.html HTTP/1.0" 200 4779 "http://www.loudacre.com"  "Loudacre Mobile Browser Ronin S2"\n233.60.251.2 - 33908 [15/Sep/2013:23:51:43 +0100] "GET /theme.css HTTP/1.0" 200 15871 "http://www.loudacre.com"  "Loudacre Mobile Browser Ronin S2"\n160.134.139.204 - 51340 [15/Sep/2013:23:50:11 +0100] "GET /KBDOC-00016.html HTTP/1.0" 200 1156 "http://www.loudacre.com"  "Loudacre Mobile Browser MeeToo 3.0"\n160.134.139.204 - 51340 [15/Sep/2013:23:50:11 +0100] "GET /theme.css HTTP/1.0" 200 13083 "http://www.loudacre.com"  "Loudacre Mobile Browser MeeToo 3.0"\n19.209.18.222 - 13392 [15/Sep/2013:23:48:48 +0100] "GET /KBDOC-00083.html HTTP/1.0" 200 4398 "http://www.loudacre.com"  "Loudacre Mobile Browser Titanic 2200"\n19.209.18.222 - 13392 [15/Sep/2013:23:48:48 +0100] "GET /theme.css HTTP/1.0" 200 4054 "http://www.loudacre.com"  "Loudacre Mobile Browser Titanic 2200"\n230.220.223.28 - 12643 [15/Sep/2013:23:48:42 +0100] "GET /KBDOC-00135.html HTTP/1.0" 200 1063 "http://www.loudacre.com"  "Loudacre Mobile Browser Sorrento F20L"\n230.220.223.28 - 12643 [15/Sep/2013:23:48:42 +0100] "GET /theme.css HTTP/1.0" 200 16864 "http://www.loudacre.com"  "Loudacre Mobile Browser Sorrento F20L"\n129.253.238.61 - 120 [15/Sep/2013:23:48:35 +0100] "GET /KBDOC-00053.html HTTP/1.0" 200 7108 "http://www.loudacre.com"  "Loudacre CSR Browser"\n129.253.238.61 - 120 [15/Sep/2013:23:48:35 +0100] "GET /theme.css HTTP/1.0" 200 19169 "http://www.loudacre.com"  "Loudacre CSR Browser"\n119.182.134.196 - 46 [15/Sep/2013:23:47:43 +0100] "GET /KBDOC-00186.html HTTP/1.0" 200 10799 "http://www.loudacre.com"  "Loudacre CSR Browser"\n119.182.134.196 - 46 [15/Sep/2013:23:47:43 +0100] "GET /theme.css HTTP/1.0" 200 19171 "http://www.loudacre.com"  "Loudacre CSR Browser"\n118.38.214.28 - 45 [15/Sep/2013:23:47:07 +0100] "GET /KBDO ...

# %%
myrdd1 = sc.textFile('/FileStore/tables/logs/2014-03*')

# %%
myrdd1.take(2)
# Out:
# ['34.28.1.122 - 65255 [01/Mar/2014:23:57:51 +0100] "GET /ifruit_3a_sales.html HTTP/1.0" 200 11416 "http://www.loudacre.com"  "Loudacre Mobile Browser Titanic 2300"',
#  '34.28.1.122 - 65255 [01/Mar/2014:23:57:51 +0100] "GET /theme.css HTTP/1.0" 200 14933 "http://www.loudacre.com"  "Loudacre Mobile Browser Titanic 2300"']

# %%
myrdd2 = myrdd1.map(lambda s:(s.split(" ")[2] , 1))

# %%
myrdd2.take(10)
# Out:
# [('65255', 1),
#  ('65255', 1),
#  ('65255', 1),
#  ('65255', 1),
#  ('96482', 1),
#  ('96482', 1),
#  ('152', 1),
#  ('152', 1),
#  ('54322', 1),
#  ('54322', 1)]

# %%
myrdd3 = myrdd2.reduceByKey(lambda a,b: a + b)

myrdd3.take(10)
# Out:
# [('197', 126),
#  ('91', 130),
#  ('58327', 4),
#  ('102728', 4),
#  ('72770', 4),
#  ('132', 152),
#  ('117273', 4),
#  ('39', 114),
#  ('127', 134),
#  ('67523', 2)]

# %%
myrdd4 = myrdd3.map(lambda pair :(pair[1] , pair[0]))

myrdd4.take(10)
# Out:
# [(126, '197'),
#  (130, '91'),
#  (4, '58327'),
#  (4, '102728'),
#  (4, '72770'),
#  (152, '132'),
#  (4, '117273'),
#  (114, '39'),
#  (134, '127'),
#  (2, '67523')]

# %%
countDict = myrdd4.countByKey()


sorted(countDict.items())
# Out:
# [(2, 11709),
#  (3, 52),
#  (4, 6580),
#  (5, 19),
#  (6, 2373),
#  (7, 11),
#  (8, 795),
#  (9, 8),
#  (10, 228),
#  (11, 2),
#  (12, 69),
#  (14, 20),
#  (16, 7),
#  (86, 1),
#  (94, 1),
#  (96, 1),
#  (98, 3),
#  (100, 3),
#  (102, 3),
#  (104, 2),
#  (106, 3),
#  (108, 4),
#  (110, 2),
#  (112, 5),
#  (114, 7),
#  (116, 10),
#  (118, 9),
#  (120, 6),
#  (122, 12),
#  (124, 12),
#  (126, 13),
#  (128, 14),
#  (130, 5),
#  (132, 10),
#  (134, 12),
#  (136, 12),
#  (138, 6),
#  (140, 11),
#  (142, 9),
#  (144, 3),
#  (146, 7),
#  (148, 3),
#  (150, 4),
#  (152, 6),
#  (154, 1),
#  (156, 1),
#  (160, 1),
#  (162, 2),
#  (164, 1),
#  (168, 1),
#  (170, 1),
#  (180, 1)]

# %%
myrdd1.take(2)
# Out:
# ['34.28.1.122 - 65255 [01/Mar/2014:23:57:51 +0100] "GET /ifruit_3a_sales.html HTTP/1.0" 200 11416 "http://www.loudacre.com"  "Loudacre Mobile Browser Titanic 2300"',
#  '34.28.1.122 - 65255 [01/Mar/2014:23:57:51 +0100] "GET /theme.css HTTP/1.0" 200 14933 "http://www.loudacre.com"  "Loudacre Mobile Browser Titanic 2300"']

# %%
myrdd6 = myrdd1.map(lambda x:(x.split(" ")[2] , x.split(" ")[0]))

myrdd6.take(10)
# Out:
# [('65255', '34.28.1.122'),
#  ('65255', '34.28.1.122'),
#  ('65255', '34.28.1.122'),
#  ('65255', '34.28.1.122'),
#  ('96482', '240.181.17.144'),
#  ('96482', '240.181.17.144'),
#  ('152', '73.33.209.18'),
#  ('152', '73.33.209.18'),
#  ('54322', '141.4.199.31'),
#  ('54322', '141.4.199.31')]

# %%
myrdd7 = myrdd6.groupByKey()
 
myrdd7.take(2)
# Out:
# [('197', <pyspark.resultiterable.ResultIterable at 0x7fd8eec9f2b0>),
#  ('91', <pyspark.resultiterable.ResultIterable at 0x7fd8eec9cfd0>)]

# %%
myrdd8 = myrdd7.map(lambda x : (x[0] , list(x[1])))
myrdd8.take(2)
# Out:
# [('197',
#   ['214.211.152.147',
#    '214.211.152.147',
#    '246.96.252.129',
#    '246.96.252.129',
#    '65.128.78.81',
#    '65.128.78.81',
#    '69.196.27.95',
#    '69.196.27.95',
#    '38.137.246.73',
#    '38.137.246.73',
#    '59.68.167.53',
#    '59.68.167.53',
#    '252.196.191.142',
#    '252.196.191.142',
#    '158.142.219.170',
#    '158.142.219.170',
#    '210.45.14.255',
#    '210.45.14.255',
#    '91.31.54.36',
#    '91.31.54.36',
#    '208.47.165.140',
#    '208.47.165.140',
#    '8.241.99.86',
#    '8.241.99.86',
#    '208.4.40.86',
#    '208.4.40.86',
#    '88.152.84.230',
#    '88.152.84.230',
#    '120.241.106.221',
#    '120.241.106.221',
#    '102.2.235.100',
#    '102.2.235.100',
#    '218.15.176.212',
#    '218.15.176.212',
#    '189.174.46.177',
#    '189.174.46.177',
#    '42.32.10.114',
#    '42.32.10.114',
#    '55.226.92.48',
#    '55.226.92.48',
#    '50.12.204.36',
#    '50.12.204.36',
#    '14.97.232.34',
#    '14.97.232.34',
#    '81.250.148.100',
#    '81.250.148.100',
#    '29.178.25.77',
#    '29.178.25.77',
#    '181.77.198.7',
#    '181.77.198.7',
#    '145.169.25.200',
#    '145.169.25.200',
#    '196.212.77.211',
#    '196.212.77.211',
#    '129.221.53.188',
#    '129.221.53.188',
#    '242.3.84.141',
#    '242.3.84.141',
#    '200.51.134.180',
#    '200.51.134.180',
#    '45.145.165.210',
#    '45.145.165.210',
#    '72.188.83.55',
#    '72.188.83.55',
#    '223.46.35.154',
#    '223.46.35.154',
#    '132.217.172.140',
#    '132.217.172.140',
#    '142.181.24.41',
#    '142.181.24.41',
#    '19.65.138.164',
#    '19.65.138.164',
#    '147.115.100.56',
#    '147.115.100.56',
#    '51.97.160.48',
#    '51.97.160.48',
#    '3.17.49.41',
#    '3.17.49.41',
#    '99.117.62.51',
#    '99.117.62.51',
#    '17.160.201.128',
#    '17.160.201.128',
#    '85.86.107.61',
#    '85.86.107.61',
#    '111.241.52.137',
#    '111.241.52.137',
#    '201.85.152.203',
#    '201.85.152.203',
#    '41.128.58.56',
#    '41.128.58.56',
#    '87.34.82.93',
#    '87.34.82.93',
#    '204.216.157.33',
#    '204.216.157.33',
#    '227.228.226.70',
#    '227.228.226.70',
#    '157.23.61.38',
#    '157.23.61.38',
#    '45.203.27.165',
#    '45.203.27.165',
#    '132.124.183.156',
#    '132.124.183.156',
#    '8.13.82.87',
#    '8.13.82.87',
#    '144.170.70.148',
#    '144.170.70.148',
#    '179.240.13.41',
#    '179.240.13.41',
#    '50.22.157.111',
#    '50.22.157.111',
#    '199.131.206.103',
#    '199.131.206.103',
#    '48.104.88.177',
#    '48.104.88.177',
#    '22.86.186.131',
#    '22.86.186.131',
#    '175.51.223.5',
#    '175.51.223.5',
#    '16.161.12.140',
#    '16.161.12.140',
#    '112.38.245.126',
#    '112.38.245.126',
#    '46.32.32.113',
#    '46.32.32.113',
#    '106.201.82.110',
#    '106.201.82.110']),
#  ('91',
#   ['57.96.41.250',
#    '57.96.41.250',
#    '182.54.253.127',
#    '182.54.253.127',
#    '143.230.125.25',
#    '143.230.125.25',
#    '114.90.214.55',
#    '114.90.214.55',
#    '18.229.40.246',
#    '18.229.40.246',
#    '174.27.171.150',
#    '174.27.171.150',
#    '145.71.216.142',
#    '145.71.216.142',
#    '67.39.116.101',
#    '67.39.116.101',
#    '65.254.253.182',
#    '65.254.253.182',
#    '48.2.128.201',
#    '48.2.128.201',
#    '200.148.22.215',
#    '200.148.22.215',
#    '112.222.42.126',
#    '112.222.42.126',
#    '24.115.217.128',
#    '24.115.217.128',
#    '230.206.67.224',
#    '230.206.67.224',
#    '20.156.25.200',
#    '20.156.25.200',
#    '146.216.61.108',
#    '146.216.61.108',
#    '168.177.155.186',
#    '168.177.155.186',
#    '171.213.56.148',
#    '171.213.56.148',
#    '74.21.212.163',
#    '74.21.212.163',
#    '145.111.27.148',
#    '145.111.27.148',
#    '119.147.59.15',
#    '119.147.59.15',
#    '196.105.197.43',
#    '196.105.197.43',
#    '83.19.114.165',
#    '83.19.114.165',
#    '103.243.84.243',
#    '103.243.84.243',
#    '120.230.28.154',
#    '120.230.28.154',
#    '206.255.162.136',
#    '206.255.162.136',
#    '232.105.215.252',
#    '232.105.215.252',
#    '201.198.176.44',
#    '201.198.176.44',
#    '109.158.69.141',
#    '109.158.69.141',
#    '112.114.189.50',
#    '112.114.189.50',
#    '124.128.152.10',
#    '124.128.152.10',
#    '60.225.185.170',
#    '60.225.185.170',
#    '44.218.192.12',
#    '44.218.192.12',
#    '39.68.88.135',
#    '39.68.88.135',
#    '36.86.34.75',
#    '36.86.34.75',
#    '96.146.86.53',
#    '96.146.86.53',
#    '198.204.201.76',
#    '198.204.201.76',
#    '146.13.204.35',
#    '146.13.204.35',
#    '233.60.98.152',
#    '233.60.98.152',
#    '227.28.131.56',
#    '227.28.131.56',
#    '51.156.113.244',
#    '51.156.113.244',
#    '37.48.57.147',
#    '37.48.57.147',
#    '116.99.175.245',
#    '116.99.175.245',
#    '173.100.53.188',
#    '173.100.53.188',
#    '54.7.3.239',
#    '54.7.3.239',
#    '37.208.165.140',
#    '37.208.165.140',
#    '49.232.255.170',
#    '49.232.255.170',
#    '250.201.162.214',
#    '250.201.162.214',
#    '129.62.183.89',
#    '129.62.183.89',
#    '231.110.204.57',
#    '231.110.204.57',
#    '196.214.239.110',
#    '196.214.239.110',
#    '89.189.143.191',
#    '89.189.143.191',
#    '77.74.108.14',
#    '77.74.108.14',
#    '193.74.79.166',
#    '193.74.79.166',
#    '129.223.160.166',
#    '129.223.160.166',
#    '36.90.82.112',
#    '36.90.82.112',
#    '105.162.74.181',
#    '105.162.74.181',
#    '198.73.49.23',
#    '198.73.49.23',
#    '145.233.162.209',
#    '145.233.162.209',
#    '153.133.184.75',
#    '153.133.184.75',
#    '206.208.125.121',
#    '206.208.125.121',
#    '23.138.39.153',
#    '23.138.39.153',
#    '137.98.218.203',
#    '137.98.218.203',
#    '30.47.173.110',
#    '30.47.173.110',
#    '106.36.141.232',
#    '106.36.141.232'])]

# %%
accountRDD1 = sc.textFile('/FileStore/tables/accounts/part-*')

accountRDD1.take(2)
# Out:
# ['1,2008-10-23 16:05:05.0,\\N,Donald,Becton,2275 Washburn Street,Oakland,CA,94660,5100032418,2014-03-18 13:29:47.0,2014-03-18 13:29:47.0',
#  '2,2008-11-12 03:00:01.0,\\N,Donna,Jones,3885 Elliott Street,San Francisco,CA,94171,4150835799,2014-03-18 13:29:47.0,2014-03-18 13:29:47.0']

# %%
accountRDD2 = accountRDD1.map(lambda x: x.split(','))

accountRDD3 = accountRDD2.map(lambda x: (x[0] , x))

accountRDD3.take(3)
# Out:
# [('1',
#   ['1',
#    '2008-10-23 16:05:05.0',
#    '\\N',
#    'Donald',
#    'Becton',
#    '2275 Washburn Street',
#    'Oakland',
#    'CA',
#    '94660',
#    '5100032418',
#    '2014-03-18 13:29:47.0',
#    '2014-03-18 13:29:47.0']),
#  ('2',
#   ['2',
#    '2008-11-12 03:00:01.0',
#    '\\N',
#    'Donna',
#    'Jones',
#    '3885 Elliott Street',
#    'San Francisco',
#    'CA',
#    '94171',
#    '4150835799',
#    '2014-03-18 13:29:47.0',
#    '2014-03-18 13:29:47.0']),
#  ('3',
#   ['3',
#    '2008-12-21 09:19:50.0',
#    '\\N',
#    'Dorthy',
#    'Chalmers',
#    '4073 Whaley Lane',
#    'San Mateo',
#    'CA',
#    '94479',
#    '6506877757',
#    '2014-03-18 13:29:47.0',
#    '2014-03-18 13:29:47.0'])]

# %%
accountRDD4 = accountRDD3.join(myrdd3)

accountRDD4.take(2)
# Out:
# [('24',
#   (['24',
#     '2008-11-13 00:08:34.0',
#     '\\N',
#     'Gwendolyn',
#     'Waters',
#     '4030 Leisure Lane',
#     'Sacramento',
#     'CA',
#     '94283',
#     '9164156733',
#     '2014-03-18 13:29:47.0',
#     '2014-03-18 13:29:47.0'],
#    128)),
#  ('33',
#   (['33',
#     '2008-12-04 11:11:21.0',
#     '\\N',
#     'Marcia',
#     'Prince',
#     '2681 Rivendell Drive',
#     'Oakland',
#     'CA',
#     '94530',
#     '5105471357',
#     '2014-03-18 13:29:47.0',
#     '2014-03-18 13:29:47.0'],
#    136))]

# %%
accountRDD5 = accountRDD4.map(lambda x: x[0] + " " + str(x[1][1]) + " " + x[1][0][3] + " " + x[1][0][4] + "\n")

accountRDD4.take(2)
# Out:
# [('24',
#   (['24',
#     '2008-11-13 00:08:34.0',
#     '\\N',
#     'Gwendolyn',
#     'Waters',
#     '4030 Leisure Lane',
#     'Sacramento',
#     'CA',
#     '94283',
#     '9164156733',
#     '2014-03-18 13:29:47.0',
#     '2014-03-18 13:29:47.0'],
#    128)),
#  ('33',
#   (['33',
#     '2008-12-04 11:11:21.0',
#     '\\N',
#     'Marcia',
#     'Prince',
#     '2681 Rivendell Drive',
#     'Oakland',
#     'CA',
#     '94530',
#     '5105471357',
#     '2014-03-18 13:29:47.0',
#     '2014-03-18 13:29:47.0'],
#    136))]

# %%
accountRDD5.take(5)
# Out:
# ['24 128 Gwendolyn Waters\n',
#  '33 136 Marcia Prince\n',
#  '56 142 Terrell Hardiman\n',
#  '70 122 Debra Newman\n',
#  '74 124 Terry Todd\n']
